# %%
# pip install -q --upgrade transformers accelerate bitsandbytes peft trl sentencepiece datasets scikit-learn unsloth tensorboardX

# %%
# Standard imports
import unsloth
from unsloth import FastLanguageModel
import pandas as pd
import torch
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    TrainingArguments,
    EarlyStoppingCallback,
    logging as hf_logging,
)
from datasets import Dataset, load_dataset
from peft import LoraConfig, PeftModel, get_peft_model, prepare_model_for_kbit_training
from trl import SFTTrainer
from sklearn.metrics import classification_report, accuracy_score
from sklearn.model_selection import train_test_split
import numpy as np
import random
import re
import os
import json # For saving/loading datasets
import textwrap
from huggingface_hub import login

# Set verbosity for Hugging Face libraries
hf_logging.set_verbosity_error() # Only show errors
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!

# %%
login(token='YOUR_HF_TOKEN_HERE')


BASE_DRIVE_PATH = "/home/user/" # ADJUST YOUR GDRIVE PATH HERE

DATA_FILE_PATH = os.path.join(BASE_DRIVE_PATH, "Dataset_ChongPha.csv") # YOUR CSV FILENAME
SUMMARY_COLUMN = 'summary'
COMMENT_COLUMN = 'comment_clean'
LABEL_COLUMN = 'label'
POSSIBLE_LABELS = ["PHAN_DONG", "KHONG_PHAN_DONG", "KHONG_LIEN_QUAN"]
# For robust matching of LLM outputs
POSSIBLE_LABELS_NORMALIZED_FOR_MATCHING = sorted([label.replace("_", "") for label in POSSIBLE_LABELS], key=len, reverse=True)
POSSIBLE_LABELS_VARIANTS_FOR_MATCHING = []
for p_label in POSSIBLE_LABELS:
    POSSIBLE_LABELS_VARIANTS_FOR_MATCHING.append(p_label.upper())
    POSSIBLE_LABELS_VARIANTS_FOR_MATCHING.append(p_label.upper().replace("_", ""))
POSSIBLE_LABELS_VARIANTS_FOR_MATCHING = sorted(list(set(POSSIBLE_LABELS_VARIANTS_FOR_MATCHING)), key=len, reverse=True)

# %%
# 1.3. Model Configuration
MODEL_ID = "Qwen/Qwen3-32B"
TOKENIZER_ID = "Qwen/Qwen3-32B"
# 1.4. Zero-Shot Testing Configuration
NUM_SAMPLES_TO_TEST_ZERO_SHOT = 9999 # Reduce for quicker initial testing, increase for more thorough
MAX_INPUT_LENGTH_ZERO_SHOT = 400  # Max length of the prompt fed to the model for zero-shot
                                  # Adjust based on analysis of your formatted prompts later
MAX_NEW_TOKENS_ZERO_SHOT = 20     # Max tokens for the model to generate (should be enough for the label)

# 1.5. Fine-tuning Configuration (QLoRA)
OUTPUT_DIR = os.path.join(BASE_DRIVE_PATH, "vistral7b") # Where to save fine-tuned model
MAX_SEQ_LENGTH_SFT = 650          # Max sequence length for SFTTrainer (prompt + completion)
                                  # This will be refined after analyzing token lengths of formatted data.
                                  # Start with a conservative value.

print("Configurations set.")
# Out:
# Configurations set.

# %%
# SYSTEM_PROMPT_CONTENT = """Phân loại bình luận mạng xã hội vào một trong ba nhóm: PHAN_DONG, KHONG_PHAN_DONG, hoặc KHONG_LIEN_QUAN. Nhiệm vụ chính là xác định chính xác bình luận có tính chất phản động đối với nhà nước Việt Nam.

# TIÊU CHÍ PHÂN LOẠI:

# PHAN_DONG:
# • Công kích, xuyên tạc, chống đối Đảng, Nhà nước, chính quyền Việt Nam
# • Phủ nhận, bóp méo sự kiện lịch sử của Việt Nam (Cách mạng, 30/4, Điện Biên Phủ...)
# • Xúc phạm lãnh đạo, biểu tượng quốc gia Việt Nam (Bác Hồ, quốc kỳ, quốc ca...)
# • Lan truyền thông tin sai lệch nhằm chống phá chế độ xã hội chủ nghĩa
# • Đồng tình với quan điểm phản động, chống phá Việt Nam trong bài đăng gốc

# KHONG_PHAN_DONG:
# • Phản biện chính sách cụ thể nhưng không phủ nhận chế độ
# • Góp ý xây dựng về đường lối, chính sách của Đảng, Nhà nước
# • Ủng hộ, bảo vệ chính quyền Việt Nam
# • Phê phán rõ ràng các quan điểm phản động
# • Bày tỏ tinh thần yêu nước, đoàn kết dân tộc Việt Nam

# KHONG_LIEN_QUAN:
# • Không đề cập đến chính trị, chính sách Việt Nam
# • Spam, quảng cáo, emoji đơn thuần
# • Nội dung đời sống, cá nhân
# • Không liên quan đến chủ đề chính trị trong bài đăng

# LƯU Ý:
# • Đồng tình với bài đăng phản động/tin giả về Việt Nam → PHAN_DONG
# • Phản bác bài đăng phản động → KHONG_PHAN_DONG
# • Bình luận mỉa mai: đánh giá ý đồ thực sự đối với nhà nước Việt Nam

# ĐỊNH DẠNG ĐẦU RA:
# Chỉ trả lời một nhãn: PHAN_DONG, KHONG_PHAN_DONG, hoặc KHONG_LIEN_QUAN"""

# SYSTEM_PROMPT_CONTENT= """Phân loại bình luận mạng xã hội vào một trong ba nhóm: PHAN_DONG, KHONG_PHAN_DONG, hoặc KHONG_LIEN_QUAN. Phân tích cả bình luận và ngữ cảnh bài đăng để xác định bình luận có tính chất phản động đối với nhà nước Việt Nam hay không.
# # ĐỊNH DẠNG ĐẦU RA:
# # Chỉ trả lời một nhãn: PHAN_DONG, KHONG_PHAN_DONG, hoặc KHONG_LIEN_QUAN"""

SYSTEM_PROMPT_CONTENT= """Phân loại bình luận mạng xã hội vào một trong ba nhóm: PHAN_DONG, KHONG_PHAN_DONG, hoặc KHONG_LIEN_QUAN. Phân tích cả bình luận và ngữ cảnh bài đăng để xác định bình luận có tính chất phản động đối với nhà nước Việt Nam hay không."""
def create_user_content(summary_text: str, comment_text: str) -> str:
    return f"""TÓM TẮT BÀI ĐĂNG:
"{summary_text}"

BÌNH LUẬN CẦN PHÂN LOẠI:
"{comment_text}"
"""

# %%
# 2.2. Load Raw Data
try:
    df_full = pd.read_csv(DATA_FILE_PATH)
    print(f"Successfully loaded data from {DATA_FILE_PATH}. Shape: {df_full.shape}")
    if not all(col in df_full.columns for col in [SUMMARY_COLUMN, COMMENT_COLUMN, LABEL_COLUMN]):
        raise ValueError(f"Missing one or more required columns: {SUMMARY_COLUMN}, {COMMENT_COLUMN}, {LABEL_COLUMN}")

    df_full[SUMMARY_COLUMN] = df_full[SUMMARY_COLUMN].fillna('').astype(str)
    df_full[COMMENT_COLUMN] = df_full[COMMENT_COLUMN].fillna('').astype(str)
    df_full[LABEL_COLUMN] = df_full[LABEL_COLUMN].astype(str).str.strip().str.upper() # Normalize labels

    # Validate labels
    invalid_labels = df_full[~df_full[LABEL_COLUMN].isin(POSSIBLE_LABELS)]
    if not invalid_labels.empty:
        print(f"Warning: Found {len(invalid_labels)} rows with invalid labels. Examples: {invalid_labels[LABEL_COLUMN].unique()[:5]}")
        print("These rows will be filtered out.")
        df_full = df_full[df_full[LABEL_COLUMN].isin(POSSIBLE_LABELS)]
        print(f"Shape after filtering invalid labels: {df_full.shape}")

    if df_full.empty:
        raise ValueError("Dataset is empty after loading or filtering. Please check your data.")

except FileNotFoundError:
    print(f"ERROR: Data file not found at {DATA_FILE_PATH}.")
    df_full = pd.DataFrame() # Avoid further errors
except ValueError as ve:
    print(f"ERROR during data loading: {ve}")
    df_full = pd.DataFrame()
except Exception as e:
    print(f"An unexpected error occurred during data loading: {e}")
    df_full = pd.DataFrame()
# Out:
# Successfully loaded data from /home/user/Dataset_ChongPha.csv. Shape: (18912, 4)

# %%
#Split Data into Train, Validation, and Test sets (80%, 10%, 10%)
if not df_full.empty:
    print("\nSplitting data into Train (70%), Validation (10%), Test (10%)...")
    # Bước 1: Tách 70% training ra, 30% còn lại cho temp (validation + test)
    df_train, df_temp = train_test_split(
        df_full,
        test_size=0.2,  # 30% cho tập tạm thời
        random_state=42,
        stratify=df_full[LABEL_COLUMN]
    )

    # Bước 2: Chia tập tạm thời (30%) thành validation (15% gốc) và test (15% gốc)
    # Điều này có nghĩa là chia tập tạm thời theo tỷ lệ 50/50
    df_val, df_test = train_test_split(
        df_temp,
        test_size=0.50,
        random_state=42,
        stratify=df_temp[LABEL_COLUMN]
    )

    print(f"Data split complete:")
    print(f"  Training set:   {len(df_train)} samples ({len(df_train)/len(df_full)*100:.1f}%)")
    print(f"  Validation set: {len(df_val)} samples ({len(df_val)/len(df_full)*100:.1f}%)")
    print(f"  Test set:       {len(df_test)} samples ({len(df_test)/len(df_full)*100:.1f}%)")

    print("\nLabel distribution in Training set:")
    print(df_train[LABEL_COLUMN].value_counts(normalize=True).sort_index())
    print("\nLabel distribution in Validation set:")
    print(df_val[LABEL_COLUMN].value_counts(normalize=True).sort_index())
    print("\nLabel distribution in Test set:")
    print(df_test[LABEL_COLUMN].value_counts(normalize=True).sort_index())

# <<< NEW: Oversample the minority class ('PHAN_DONG') in the training set (df_train) >>>
if not df_train.empty:
    print(f"\nOriginal df_train label distribution:")
    print(df_train[LABEL_COLUMN].value_counts(normalize=True).sort_index())

    # Identify minority and majority classes
    label_counts = df_train[LABEL_COLUMN].value_counts()
    majority_class_count = label_counts.max()
    minority_class = "PHAN_DONG" # Your specific minority class
    minority_class_count = label_counts.get(minority_class, 0)

    if minority_class_count > 0 and minority_class_count < majority_class_count:
        print(f"Oversampling minority class '{minority_class}' from {minority_class_count} to match majority (or a higher target)...")
        # Simple oversampling: duplicate minority samples
        # You can choose a target count, e.g., match the majority, or a fraction of it.
        # Let's aim to bring it closer to the next class or a significant portion of majority.
        # For simplicity, let's try to increase its count, e.g., to be similar to KHONG_PHAN_DONG
        target_count_for_minority = label_counts.get("KHONG_PHAN_DONG", majority_class_count) # Or a fixed number

        df_minority = df_train[df_train[LABEL_COLUMN] == minority_class]

        # Calculate how many times to replicate
        if minority_class_count > 0: # Avoid division by zero
            num_replications = (target_count_for_minority // minority_class_count) -1
            if num_replications < 0: num_replications = 0 # Should not happen if target > current

            df_oversampled_minority = pd.concat([df_minority] * num_replications, ignore_index=True)

            # Add remaining samples to get closer to target_count
            remaining_samples_needed = target_count_for_minority % minority_class_count
            if remaining_samples_needed > 0 and not df_minority.empty:
                df_oversampled_minority = pd.concat([df_oversampled_minority, df_minority.sample(n=remaining_samples_needed, replace=True, random_state=42)], ignore_index=True)

            df_train_oversampled = pd.concat([df_train, df_oversampled_minority], ignore_index=True)

            # Shuffle the oversampled training data
            df_train = df_train_oversampled.sample(frac=1, random_state=42).reset_index(drop=True)
            print(f"\nOversampled df_train label distribution:")
            print(df_train[LABEL_COLUMN].value_counts().sort_index())
    else:
        print(f"Minority class '{minority_class}' not found or no oversampling needed/possible.")
# <<< END OF OVERSAMPLING SECTION >>>
# Out:
# Splitting data into Train (70%), Validation (10%), Test (10%)...
# Data split complete:
#   Training set:   15129 samples (80.0%)
#   Validation set: 1891 samples (10.0%)
#   Test set:       1892 samples (10.0%)
#
# Label distribution in Training set:
# label
# KHONG_LIEN_QUAN    0.528984
# KHONG_PHAN_DONG    0.356600
# PHAN_DONG          0.114416
# Name: proportion, dtype: float64
#
# Label distribution in Validation set:
# label
# KHONG_LIEN_QUAN    0.528821
# KHONG_PHAN_DONG    0.356425
# PHAN_DONG          0.114754
# Name: proportion, dtype: float64
#
# Label distribution in Test set:
# label
# KHONG_LIEN_QUAN    0.529070
# KHONG_PHAN_DONG    0.356765
# PHAN_DONG          0.114165
# Name: proportion, dtype: float64
#
# Original df_train label distribution:
# label
# KHONG_LIEN_QUAN    0.528984
# KHONG_PHAN_DONG    0.356600
# PHAN_DONG          0.114416
# Name: proportion, dtype: float64
# Oversampling minority class 'PHAN_DONG' from 1731 to match majority (or a higher target)...
#
# Oversampled df_train label distribution:
# label
# KHONG_LIEN_QUAN    8003
# KHONG_PHAN_DONG    5395
# PHAN_DONG          5395
# Name: count, dtype: int64

# %%
num_samples_for_zs = min(NUM_SAMPLES_TO_TEST_ZERO_SHOT, len(df_test))
if num_samples_for_zs > 0 :
    df_zero_shot_evaluation_set = df_test.sample(n=num_samples_for_zs, random_state=42)
    print(f"\nUsing {len(df_zero_shot_evaluation_set)} samples from the new Test set for zero-shot baseline evaluation.")
    if not df_zero_shot_evaluation_set.empty:
        print("Label distribution in zero-shot evaluation sample:")
        print(df_zero_shot_evaluation_set[LABEL_COLUMN].value_counts(normalize=True).sort_index())
else:
    print("Test set is too small or NUM_SAMPLES_TO_TEST_ZERO_SHOT is 0, skipping zero-shot sample creation.")
    df_zero_shot_evaluation_set = pd.DataFrame() # Đảm bảo là DataFrame rỗng
# Out:
# Using 1892 samples from the new Test set for zero-shot baseline evaluation.
# Label distribution in zero-shot evaluation sample:
# label
# KHONG_LIEN_QUAN    0.529070
# KHONG_PHAN_DONG    0.356765
# PHAN_DONG          0.114165
# Name: proportion, dtype: float64

# %%
model_for_zs, tokenizer_for_zs = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Qwen3-32B-unsloth-bnb-4bit",
    max_seq_length = MAX_SEQ_LENGTH_SFT,
    load_in_4bit = True,
    # token = "hf_...", # use one if using gated models like meta-llama/Llama-2-7b-hf
)
FastLanguageModel.for_inference(model_for_zs)
print("Model and Tokenizer for Zero-Shot loaded.")
# Out:
# ==((====))==  Unsloth 2025.7.11: Fast Qwen3 patching. Transformers: 4.54.1.
#    \\   /|    NVIDIA L40S. Num GPUs = 1. Max memory: 44.403 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.7.1+cu128. CUDA: 8.9. CUDA Toolkit: 12.8. Triton: 3.3.1
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.31.post1. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading checkpoint shards:   0%|          | 0/9 [00:00<?, ?it/s]
# Model and Tokenizer for Zero-Shot loaded.

# %%
# Interactive Testing on Full Test Dataset
print("\n--- Interactive Testing on Full Test Dataset ---")

print(f"Running interactive testing on {len(df_test)} test samples...")

correct_predictions = 0
total_predictions = 0
all_actual_labels = []
all_predicted_labels = []

for idx, row in df_test.iterrows():
    # Reset conversation for each test sample
    conversation = [{"role": "system", "content": SYSTEM_PROMPT_CONTENT}]

    # Get the test data
    post = row[SUMMARY_COLUMN]
    comment = row[COMMENT_COLUMN]
    actual_label = row[LABEL_COLUMN]

    # Create user content and add to conversation
    user_content = create_user_content(post, comment)
    conversation.append({"role": "user", "content": user_content})

    # Tokenize and generate response
    input_ids = tokenizer_for_zs.apply_chat_template(
        conversation,
        return_tensors="pt",
        enable_thinking=False,
        add_generation_prompt=True
    ).to(model_for_zs.device)

    out_ids = model_for_zs.generate(
        input_ids=input_ids,
        max_new_tokens=100,
        do_sample=True,
        top_p=0.95,
        top_k=40,
        temperature=0.1,
        repetition_penalty=1.05,
        pad_token_id=tokenizer_for_zs.eos_token_id,
        eos_token_id=tokenizer_for_zs.eos_token_id
    )

    # Decode the assistant response
    assistant_response = tokenizer_for_zs.batch_decode(
        out_ids[:, input_ids.size(1):],
        skip_special_tokens=True
    )[0].strip()

    # Extract predicted label using your existing logic
    extracted_label = "NULL"
    normalized_response = re.sub(r'[^\w_]', '', assistant_response.upper().replace(" ", "_"))
    normalized_response = re.sub(r'_+', '_', normalized_response)

    for variant in POSSIBLE_LABELS_VARIANTS_FOR_MATCHING:
        if variant in normalized_response:
            if variant in POSSIBLE_LABELS_NORMALIZED_FOR_MATCHING:
                original_label_index = POSSIBLE_LABELS_NORMALIZED_FOR_MATCHING.index(variant)
                extracted_label = POSSIBLE_LABELS[original_label_index]
            else:
                for pl_original in POSSIBLE_LABELS:
                    if pl_original.upper() == variant:
                        extracted_label = pl_original
                        break
            break

    # Track results
    all_actual_labels.append(actual_label)
    all_predicted_labels.append(extracted_label)
    total_predictions += 1

    if extracted_label == actual_label:
        correct_predictions += 1

    # Print detailed results for ALL samples (removed the <= 10 condition)
    print(f"\nSample {total_predictions}:")
    print(f"  Assistant Response: {assistant_response}")
    print(f"  Predicted: {extracted_label} | Actual: {actual_label} | {'✓' if extracted_label == actual_label else '✗'}")

    # Print progress every 50 samples
    if total_predictions % 50 == 0:
        current_accuracy = correct_predictions / total_predictions
        print(f"\n=== Progress Update ===")
        print(f"Processed {total_predictions} samples. Current accuracy: {current_accuracy:.4f}")
        print("=" * 40)

# Final results
final_accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0
print(f"\n=== Final Test Results ===")
print(f"Total samples processed: {total_predictions}")
print(f"Correct predictions: {correct_predictions}")
print(f"Test Accuracy: {final_accuracy:.4f}")

# Classification report
if all_actual_labels and all_predicted_labels:
    print("\nTest Classification Report:")
    print(classification_report(
        all_actual_labels,
        all_predicted_labels,
        labels=POSSIBLE_LABELS,
        target_names=POSSIBLE_LABELS,
        zero_division=0
    ))
# Out:
# --- Interactive Testing on Full Test Dataset ---
# Running interactive testing on 1892 test samples...
#
# Sample 1:
#   Assistant Response: PHAN_DONG
#   Predicted: PHAN_DONG | Actual: KHONG_LIEN_QUAN | ✗
#
# Sample 2:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# Sample 3:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# Sample 4:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# Sample 5:
#   Assistant Response: PHAN_DONG
#   Predicted: PHAN_DONG | Actual: PHAN_DONG | ✓
#
# Sample 6:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# Sample 7:
#   Assistant Response: PHAN_DONG
#   Predicted: PHAN_DONG | Actual: PHAN_DONG | ✓
#
# Sample 8:
#   Assistant Response: KHONG_PHAN_DONG
#   Predicted: KHONG_PHAN_DONG | Actual: KHONG_PHAN_DONG | ✓
#
# Sample 9:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_PHAN_DONG | ✗
#
# Sample 10:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# Sample
FastLanguageModel.from_pretrained(
    model_name = "unsloth/Qwen3-32B-unsloth-bnb-4bit",
    max_seq_length = MAX_SEQ_LENGTH_SFT,
    load_in_4bit = True,
    # token = "hf_...", # use one if using gated models like meta-llama/Llama-2-7b-hf
)
print("Model prepared for k-bit training.")
model_sft = FastLanguageModel.get_peft_model(
    model_sft,
    r=32,
    lora_alpha=64,
    target_modules=[
          "q_proj",
          "k_proj",
          "v_proj",
          "o_proj",
          "up_proj",
          "down_proj",
          "gate_proj"
      ],
    bias="none",
)
print("LoRA config defined.")
# Out:
# ==((====))==  Unsloth 2025.7.11: Fast Qwen3 patching. Transformers: 4.54.1.
#    \\   /|    NVIDIA L40S. Num GPUs = 1. Max memory: 44.403 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.7.1+cu128. CUDA: 8.9. CUDA Toolkit: 12.8. Triton: 3.3.1
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.31.post1. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading checkpoint shards:   0%|          | 0/9 [00:00<?, ?it/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/707 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# Model prepared for k-bit training.
# LoRA config defined.

# %%
# 2.4. Prepare Dataset for Fine-tuning (Conversational Format)
alpaca_prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
Phân loại bình luận mạng xã hội vào một trong ba nhóm: PHAN_DONG, KHONG_PHAN_DONG, hoặc KHONG_LIEN_QUAN. Phân tích cả bình luận và ngữ cảnh bài đăng để xác định bình luận có tính chất phản động đối với nhà nước Việt Nam hay không.
ĐỊNH DẠNG ĐẦU RA:
Chỉ trả lời một nhãn: PHAN_DONG, KHONG_PHAN_DONG, hoặc KHONG_LIEN_QUAN

### Input:
{}

### Response:
{}"""

EOS_TOKEN = tokenizer_sft.eos_token # Must add EOS_TOKEN

def create_user_content(summary_text, comment_text):
    return f"""TÓM TẮT BÀI ĐĂNG:
"{summary_text}"

BÌNH LUẬN CẦN PHÂN LOẠI:
"{comment_text}" """

def formatting_prompts_func(sample):
    instruction = """Phân loại bình luận mạng xã hội vào một trong ba nhóm: PHAN_DONG, KHONG_PHAN_DONG, hoặc KHONG_LIEN_QUAN. Phân tích cả bình luận và ngữ cảnh bài đăng để xác định bình luận có tính chất phản động đối với nhà nước Việt Nam hay không."""
    
    user_content = create_user_content(sample[SUMMARY_COLUMN], sample[COMMENT_COLUMN])
    output = sample[LABEL_COLUMN]
    
    # Important: Format the text exactly as expected by the model
    formatted_text = f"### Instruction: {instruction}\n\n### Input: {user_content}\n\n### Response: {output}{tokenizer_sft.eos_token}"
    return {"text": formatted_text}


# # Sử dụng hàm định dạng với dataset của bạn
# dataset = dataset.map(formatting_prompts_func, batched=True)

# %%
train_hf_dataset = Dataset.from_pandas(df_train)
val_hf_dataset = Dataset.from_pandas(df_val)
# df_test cũng sẽ được dùng để tạo test_hf_dataset cho đánh giá cuối cùng của model đã fine-tune
train_sft_formatted = train_hf_dataset.map(
    formatting_prompts_func,
    batched=False,
    remove_columns=train_hf_dataset.column_names  # Remove original columns
)

val_sft_formatted = val_hf_dataset.map(
    formatting_prompts_func,
    batched=False,
    remove_columns=val_hf_dataset.column_names  # Remove original columns
)
# from datasets import DatasetDict
# raw_datasets_sft = DatasetDict({
#     'train': train_sft_formatted,
#     'validation': val_sft_formatted # Đổi tên key cho tập validation
# })
print(f"\nDataset for SFT prepared:")
print(f"SFT Training set size:   {len(train_sft_formatted)}")
print(f"SFT Validation set size: {len(val_sft_formatted)}")
# ... (phần in ví dụ dữ liệu SFT giữ nguyên) ...

# %%
val_sft_formatted['text'][0]
# Out:
# '### Instruction: Phân loại bình luận mạng xã hội vào một trong ba nhóm: PHAN_DONG, KHONG_PHAN_DONG, hoặc KHONG_LIEN_QUAN. Phân tích cả bình luận và ngữ cảnh bài đăng để xác định bình luận có tính chất phản động đối với nhà nước Việt Nam hay không.\n\n### Input: TÓM TẮT BÀI ĐĂNG:\n"1. Nội dung sơ lược: Một người đang tuyên truyền ở Cali thì bị cảnh sát bắt.\n\n2. Vấn đề: Hoạt động tuyên truyền bất hợp pháp ở Cali dẫn đến việc bị cảnh sát can thiệp.\n\n3. Phản động/tin giả: Không rõ ràng. Cần biết nội dung tuyên truyền là gì để xác định. Nếu nội dung chống phá nhà nước Việt Nam thì có thể coi là phản động."\n\nBÌNH LUẬN CẦN PHÂN LOẠI:\n"bạn nuôi con chó đến khi nó bắt đầu phá phách và cắn giày của bạn thì bạn phải phạt nó chứ" \n\n### Response: KHONG_LIEN_QUAN<|im_end|>'

# %%
 # --- Phase 4: Fine-tune LLM using SFTTrainer ---
early_stopping_callback = EarlyStoppingCallback(
    early_stopping_patience=2,
    early_stopping_threshold=0.001
)
training_args_sft = TrainingArguments(
    output_dir=OUTPUT_DIR,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=32,
    gradient_accumulation_steps=2,
    optim="paged_adamw_8bit",
    learning_rate=6e-5,
    num_train_epochs=2,
    warmup_ratio=0.15,
    weight_decay=0.02,
    bf16=True, # Default to FP16, BF16 handled below if supported
    logging_steps=50,
    eval_strategy="steps",
    eval_steps=100,
    save_steps=300,
    save_total_limit=2,
    load_best_model_at_end=True,
    metric_for_best_model="eval_loss",
    greater_is_better=True,
    report_to="tensorboard",
    push_to_hub=False,
    gradient_checkpointing=True,
    gradient_checkpointing_kwargs={'use_reentrant':False}
)

print("TrainingArguments defined.")

trainer_sft = SFTTrainer(
    model=model_sft,
    args=training_args_sft,
    train_dataset=train_sft_formatted,
    eval_dataset=val_sft_formatted,
    dataset_text_field="text",
    max_seq_length = MAX_SEQ_LENGTH_SFT,
    tokenizer=tokenizer_sft,
    # formatting_func=formatting_prompts_func,
    callbacks=[early_stopping_callback]
)
print("SFTTrainer initialized.")
print("\nStarting SFT fine-tuning...")
trainer_sft.train()
print("SFT Fine-tuning finished.")
print(f"Saving LoRA adapter to {OUTPUT_DIR}...")
trainer_sft.save_model(OUTPUT_DIR)
tokenizer_sft.save_pretrained(OUTPUT_DIR)
print("LoRA adapter and tokenizer saved.")
# Out:
# TrainingArguments defined.
# Unsloth: Tokenizing ["text"]:   0%|          | 0/18793 [00:00<?, ? examples/s]
# Unsloth: Tokenizing ["text"]:   0%|          | 0/1891 [00:00<?, ? examples/s]
# SFTTrainer initialized.
#
# Starting SFT fine-tuning...
# {'loss': 2.0091, 'grad_norm': 0.5195155739784241, 'learning_rate': 1.6610169491525424e-05, 'epoch': 0.0851063829787234}
# {'loss': 0.9874, 'grad_norm': 0.32032981514930725, 'learning_rate': 3.35593220338983e-05, 'epoch': 0.1702127659574468}
# {'eval_loss': 0.7535689473152161, 'eval_runtime': 104.9298, 'eval_samples_per_second': 18.022, 'eval_steps_per_second': 0.572, 'epoch': 0.1702127659574468}
# {'loss': 0.5811, 'grad_norm': 0.3375454545021057, 'learning_rate': 5.050847457627119e-05, 'epoch': 0.2553191489361702}
# {'loss': 0.4506, 'grad_norm': 0.23045852780342102, 'learning_rate': 5.867867867867868e-05, 'epoch': 0.3404255319148936}
# {'eval_loss': 0.4344872236251831, 'eval_runtime': 103.745, 'eval_samples_per_second': 18.227, 'eval_steps_per_second': 0.578, 'epoch': 0.3404255319148936}
# {'loss': 0.4457, 'grad_norm': 0.19075872004032135, 'learning_rate': 5.567567567567567e-05, 'epoch': 0.425531914893617}
# {'loss': 0.4257, 'grad_norm': 0.5533307194709778, 'learning_rate': 5.267267267267267e-05, 'epoch': 0.5106382978723404}
# {'eval_loss': 0.4239223003387451, 'eval_runtime': 104.2604, 'eval_samples_per_second': 18.137, 'eval_steps_per_second': 0.575, 'epoch': 0.5106382978723404}
# {'train_runtime': 1817.5203, 'train_samples_per_second': 20.68, 'train_steps_per_second': 0.647, 'train_loss': 0.8166059875488281, 'epoch': 0.5106382978723404}
# SFT Fine-tuning finished.
# Saving LoRA adapter to /home/user/vistral7b...
# LoRA adapter and tokenizer saved.

# %%
# Interactive Testing on Full Test Dataset with Unsloth
print("\n--- Interactive Testing on Full Test Dataset (Unsloth) ---")
# model_sft, tokenizer_sft = FastLanguageModel.from_pretrained(
#     model_name = "qwen32b", # YOUR MODEL YOU USED FOR TRAINING
#     load_in_4bit = True,
# )
# # Enable faster inference with Unsloth
# FastLanguageModel.for_inference(model_sft)

if 'model_sft' in locals() and 'tokenizer_sft' in locals() and not df_test.empty:
    print(f"Running interactive testing on {len(df_test)} test samples...")

    correct_predictions = 0
    total_predictions = 0
    all_actual_labels = []
    all_predicted_labels = []

    for idx, row in df_test.iterrows():
        # Get the test data
        post = row[SUMMARY_COLUMN]
        comment = row[COMMENT_COLUMN]
        actual_label = row[LABEL_COLUMN]
        
        # Create user content
        user_content = create_user_content(post, comment)
        
        # Use the same format as in training, but without the response
        instruction = """Phân loại bình luận mạng xã hội vào một trong ba nhóm: PHAN_DONG, KHONG_PHAN_DONG, hoặc KHONG_LIEN_QUAN. Phân tích cả bình luận và ngữ cảnh bài đăng để xác định bình luận có tính chất phản động đối với nhà nước Việt Nam hay không."""
        
        # Format prompt for inference - notice we stop at "### Response:" and let the model continue
        formatted_input = f"### Instruction: {instruction}\n\n### Input: {user_content}\n\n### Response:"
        
        # Tokenize input
        inputs = tokenizer_sft([formatted_input], return_tensors="pt").to(model_sft.device)
        
        # Generate response
        output_ids = model_sft.generate(
            **inputs,
            max_new_tokens=20,
            do_sample=True,
            top_p=0,
            top_k=1,
            temperature=0.1,
            repetition_penalty=1.05,
            pad_token_id=tokenizer_sft.eos_token_id,
            eos_token_id=tokenizer_sft.eos_token_id
        )
        
        # Decode the response
        assistant_response = tokenizer_sft.decode(
            output_ids[0, inputs.input_ids.shape[1]:],
            skip_special_tokens=True
        ).strip()
        
        # Extract predicted label using existing logic
        extracted_label = "NULL"
        normalized_response = re.sub(r'[^\w_]', '', assistant_response.upper().replace(" ", "_"))
        normalized_response = re.sub(r'_+', '_', normalized_response)

        for variant in POSSIBLE_LABELS_VARIANTS_FOR_MATCHING:
            if variant in normalized_response:
                if variant in POSSIBLE_LABELS_NORMALIZED_FOR_MATCHING:
                    original_label_index = POSSIBLE_LABELS_NORMALIZED_FOR_MATCHING.index(variant)
                    extracted_label = POSSIBLE_LABELS[original_label_index]
                else:
                    for pl_original in POSSIBLE_LABELS:
                        if pl_original.upper() == variant:
                            extracted_label = pl_original
                            break
                break

        # Track results
        all_actual_labels.append(actual_label)
        all_predicted_labels.append(extracted_label)
        total_predictions += 1

        if extracted_label == actual_label:
            correct_predictions += 1

        # Print detailed results for all samples
        print(f"\nSample {total_predictions}:")
        print(f"  Assistant Response: {assistant_response}")
        print(f"  Predicted: {extracted_label} | Actual: {actual_label} | {'✓' if extracted_label == actual_label else '✗'}")

        # Print progress every 50 samples
        if total_predictions % 50 == 0:
            current_accuracy = correct_predictions / total_predictions
            print(f"\n=== Progress Update ===")
            print(f"Processed {total_predictions} samples. Current accuracy: {current_accuracy:.4f}")
            print("=" * 40)

    # Final results
    final_accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0

#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# Sample 1840:
#   Assistant Response: KHONG_PHAN_DONG
#   Predicted: KHONG_PHAN_DONG | Actual: KHONG_LIEN_QUAN | ✗
#
# Sample 1841:
#   Assistant Response: KHONG_PHAN_DONG
#   Predicted: KHONG_PHAN_DONG | Actual: KHONG_LIEN_QUAN | ✗
#
# Sample 1842:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# Sample 1843:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# Sample 1844:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# Sample 1845:
#   Assistant Response: PHAN_DONG
#   Predicted: PHAN_DONG | Actual: KHONG_LIEN_QUAN | ✗
#
# Sample 1846:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_PHAN_DONG | ✗
#
# Sample 1847:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# Sample 1848:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_PHAN_DONG | ✗
#
# Sample 1849:
#   Assistant Response: KHONG_PHAN_DONG
#   Predicted: KHONG_PHAN_DONG | Actual: KHONG_PHAN_DONG | ✓
#
# Sample 1850:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# === Progress Update ===
# Processed 1850 samples. Current accuracy: 0.6800
# ========================================
#
# Sample 1851:
#   Assistant Response: PHAN_DONG
#   Predicted: PHAN_DONG | Actual: KHONG_PHAN_DONG | ✗
#
# Sample 1852:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# Sample 1853:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# Sample 1854:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_PHAN_DONG | ✗
#
# Sample 1855:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: PHAN_DONG | ✗
#
# Sample 1856:
#   Assistant Response: PHAN_DONG
#   Predicted: PHAN_DONG | Actual: PHAN_DONG | ✓
#
# Sample 1857:
#   Assistant Response: KHONG_PHAN_DONG
#   Predicted: KHONG_PHAN_DONG | Actual: KHONG_PHAN_DONG | ✓
#
# Sample 1858:
#   Assistant Response: KHONG_PHAN_DONG
#   Predicted: KHONG_PHAN_DONG | Actual: KHONG_PHAN_DONG | ✓
#
# Sample 1859:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# Sample 1860:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# Sample 1861:
#   Assistant Response: KHONG_PHAN_DONG
#   Predicted: KHONG_PHAN_DONG | Actual: KHONG_PHAN_DONG | ✓
#
# Sample 1862:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# Sample 1863:
#   Assistant Response: KHONG_PHAN_DONG
#   Predicted: KHONG_PHAN_DONG | Actual: KHONG_LIEN_QUAN | ✗
#
# Sample 1864:
#   Assistant Response: PHAN_DONG
#   Predicted: PHAN_DONG | Actual: KHONG_LIEN_QUAN | ✗
#
# Sample 1865:
#   Assistant Response: KHONG_PHAN_DONG
#   Predicted: KHONG_PHAN_DONG | Actual: KHONG_PHAN_DONG | ✓
#
# Sample 1866:
#   Assistant Response: PHAN_DONG
#   Predicted: PHAN_DONG | Actual: KHONG_PHAN_DONG | ✗
#
# Sample 1867:
#   Assistant Response: KHONG_PHAN_DONG
#   Predicted: KHONG_PHAN_DONG | Actual: PHAN_DONG | ✗
#
# Sample 1868:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# Sample 1869:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# Sample 1870:
#   Assistant Response: PHAN_DONG
#   Predicted: PHAN_DONG | Actual: KHONG_LIEN_QUAN | ✗
#
# Sample 1871:
#   Assistant Response: PHAN_DONG
#   Predicted: PHAN_DONG | Actual: KHONG_PHAN_DONG | ✗
#
# Sample 1872:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_PHAN_DONG | ✗
#
# Sample 1873:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# Sample 1874:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# Sample 1875:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# Sample 1876:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# Sample 1877:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# Sample 1878:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_PHAN_DONG | ✗
#
# Sample 1879:
#   Assistant Response: KHONG_PHAN_DONG
#   Predicted: KHONG_PHAN_DONG | Actual: KHONG_PHAN_DONG | ✓
#
# Sample 1880:
#   Assistant Response: KHONG_PHAN_DONG
#   Predicted: KHONG_PHAN_DONG | Actual: KHONG_LIEN_QUAN | ✗
#
# Sample 1881:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# Sample 1882:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# Sample 1883:
#   Assistant Response: KHONG_PHAN_DONG
#   Predicted: KHONG_PHAN_DONG | Actual: KHONG_PHAN_DONG | ✓
#
# Sample 1884:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# Sample 1885:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# Sample 1886:
#   Assistant Response: PHAN_DONG
#   Predicted: PHAN_DONG | Actual: PHAN_DONG | ✓
#
# Sample 1887:
#   Assistant Response: KHONG_PHAN_DONG
#   Predicted: KHONG_PHAN_DONG | Actual: KHONG_LIEN_QUAN | ✗
#
# Sample 1888:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# Sample 1889:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# Sample 1890:
#   Assistant Response: KHONG_PHAN_DONG
#   Predicted: KHONG_PHAN_DONG | Actual: KHONG_PHAN_DONG | ✓
#
# Sample 1891:
#   Assistant Response: KHONG_LIEN_QUAN
#   Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# Sample 1892:
#   Assistant Response: PHAN_DONG
#   Predicted: PHAN_DONG | Actual: PHAN_DONG | ✓
#
# === Final Test Results ===
# Total samples processed: 1892
# Correct predictions: 1287
# Test Accuracy: 0.6802
#
# Test Classification Report:
#                  precision    recall  f1-score   support
#
#       PHAN_DONG       0.43      0.72      0.54       216
# KHONG_PHAN_DONG       0.65      0.55      0.59       675
# KHONG_LIEN_QUAN       0.79      0.76      0.78      1001
#
#        accuracy                           0.68      1892
#       macro avg       0.62      0.68      0.64      1892
#    weighted avg       0.70      0.68      0.68      1892

# %%
# Interactive Testing on Full Test Dataset with Unsloth
print("\n--- Interactive Testing on Full Test Dataset (Unsloth) ---")
# model_sft, tokenizer_sft = FastLanguageModel.from_pretrained(
#     model_name = "qwen32b", # YOUR MODEL YOU USED FOR TRAINING
#     load_in_4bit = True,
# )
# # Enable faster inference with Unsloth
# FastLanguageModel.for_inference(model_sft)

if 'model_sft' in locals() and 'tokenizer_sft' in locals() and not df_test.empty:
    print(f"Running interactive testing on {len(df_test)} test samples...")

    correct_predictions = 0
    total_predictions = 0
    all_actual_labels = []
    all_predicted_labels = []

    for idx, row in df_test.iterrows():
        # Get the test data
        post = row[SUMMARY_COLUMN]
        comment = row[COMMENT_COLUMN]
        actual_label = row[LABEL_COLUMN]
        
        # Create user content
        user_content = create_user_content(post, comment)
        
        # Use the same format as in training, but without the response
        instruction = """Phân loại bình luận mạng xã hội vào một trong ba nhóm: PHAN_DONG, KHONG_PHAN_DONG, hoặc KHONG_LIEN_QUAN. Phân tích cả bình luận và ngữ cảnh bài đăng để xác định bình luận có tính chất phản động đối với nhà nước Việt Nam hay không.
        #Trả lời bằng nhãn phân loại sau đó đưa ra giải thích e.g. Response: PHAN_DONG \n Giải thích: *giải thích* """
        
        # Format prompt for inference - notice we stop at "### Response:" and let the model continue
        formatted_input = f"### Instruction: {instruction}\n\n### Input: {user_content}\n\n### Response:"
        
        # Tokenize input
        inputs = tokenizer_sft([formatted_input], return_tensors="pt").to(model_sft.device)
        
        # Generate response
        output_ids = model_sft.generate(
            **inputs,
            max_new_tokens=256,
            do_sample=True,
            top_p=0.8,
            top_k=20,
            temperature=0.4,
            repetition_penalty=1.05,
            pad_token_id=tokenizer_sft.eos_token_id,
            eos_token_id=tokenizer_sft.eos_token_id
        )
        
        # Decode the response
        assistant_response = tokenizer_sft.decode(
            output_ids[0, inputs.input_ids.shape[1]:],
            skip_special_tokens=True
        ).strip()
        
        # Extract predicted label using existing logic
        extracted_label = "NULL"
        normalized_response = re.sub(r'[^\w_]', '', assistant_response.upper().replace(" ", "_"))
        normalized_response = re.sub(r'_+', '_', normalized_response)

        for variant in POSSIBLE_LABELS_VARIANTS_FOR_MATCHING:
            if variant in normalized_response:
                if variant in POSSIBLE_LABELS_NORMALIZED_FOR_MATCHING:
                    original_label_index = POSSIBLE_LABELS_NORMALIZED_FOR_MATCHING.index(variant)
                    extracted_label = POSSIBLE_LABELS[original_label_index]
                else:
                    for pl_original in POSSIBLE_LABELS:
                        if pl_original.upper() == variant:
                            extracted_label = pl_original
                            break
                break

        # Track results
        all_actual_labels.append(actual_label)
        all_predicted_labels.append(extracted_label)
        total_predictions += 1

        if extracted_label == actual_label:
            correct_predictions += 1

        # Print detailed results for all samples
        print(f"\n-----------------------------------------Sample {total_predictions}:-----------------------------------------")
        print(f"Post: \n{post}")
        print(f"Comment: {comment}")
        print(f"\nAssistant Response: {assistant_response}")
        print(f"\nPredicted: {extracted_label} | Actual: {actual_label} | {'✓' if extracted_label == actual_label else '✗'}")
        # Print progress every 50 samples
        if total_predictions % 50 == 0:
            current_accuracy = correct_predictions / total_predictions
            print(f"\n=== Progress Update ===")
            print(f"Processed {total_predictions} samples. Current accuracy: {current_accuracy:.4f}")
            print("=" * 40)

    # Final results
    final_accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0
    print(f"\n=== Final Test Results ===")
    print(f"Total samples processed: {total_predictions}")
    print(f"Correct predictions: {correct_predictions}")
    print(f"Test Accuracy: {final_accuracy:.4f}")

    # Classification report
    if all_actual_labels and all_predicted_labels:
        print("\nTest Classification Report:")
        print(classification_report(
            all_actual_labels,
            all_predicted_labels,
            labels=POSSIBLE_LABELS,
            target_names=POSSIBLE_LABELS,
            zero_division=0
        ))

else:
    if 'model_sft' not in locals() or 'tokenizer_sft' not in locals():
        print("Fine-tuned model or tokenizer not available. Please run the fine-tuning section first.")
    if df_test.empty:
        print("Test dataset is empty.")
# Out:
# --- Interactive Testing on Full Test Dataset (Unsloth) ---
# Running interactive testing on 1892 test samples...
#
# -----------------------------------------Sample 1:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Bài viết kể về cuộc sống sung túc của một gia đình ở miền Nam trước năm 1975, sau đó bị đảo lộn do 'giải phóng'. Tác giả bày tỏ sự tiếc nuối và đau khổ về những mất mát mà gia đình và đồng bào phải chịu đựng.
#
# 2. Vấn đề: Tính chủ quan trong việc đánh giá về giai đoạn lịch sử. Mặc dù thể hiện nỗi đau cá nhân, nhưng có thể bị lợi dụng để xuyên tạc lịch sử.
#
# 3. Phản động/tin giả: Có thể. Mặc dù bài viết chủ yếu thể hiện nỗi đau cá nhân, nhưng việc tập trung vào những mất mát và sử dụng ngôn ngữ gợi nhớ về một 'hòn ngọc viễn đông' có thể bị lợi dụng để xuyên tạc lịch sử và kích động tâm lý chống đối.
# Comment: bám đít mỹ có miến ăn hả
#
# Assistant Response: KHONG_PHAN_DONG
# Giải thích: Bình luận ngắn gọn "bám đít mỹ có miến ăn hả" mang tính chất châm biếm, chỉ trích việc phụ thuộc vào nước ngoài (trong trường hợp này là Mỹ). Mặc dù có tính chất chỉ trích, nhưng nó không trực tiếp thể hiện thái độ chống phá chính quyền hay chế độ hiện tại. Thay vào đó, nó phản ánh một quan điểm về sự phụ thuộc kinh tế và ngoại giao vào các cường quốc nước ngoài, điều này có thể được xem là một ý kiến trái chiều nhưng không mang tính chất phản động rõ ràng. Không có dấu hiệu xuyên tạc lịch sử hay kích động bạo lực. Do đó, bình luận này thuộc nhóm KHÔNG_PHẢN_ĐỘNG.
#
# Predicted: KHONG_PHAN_DONG | Actual: KHONG_LIEN_QUAN | ✗
#
# -----------------------------------------Sample 2:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Văn bản ca ngợi một "đội hình" các nhân vật lịch sử đã "cứu nước" trong giai đoạn khó khăn của Việt Nam.
# 2. Vấn đề: Sử dụng ngôn ngữ mang tính chất tuyên truyền, ca ngợi một cách chung chung mà không nêu rõ bối cảnh lịch sử cụ thể.
# 3. Phản động/tin giả: không, văn bản mang tính chất ca ngợi lịch sử, không có dấu hiệu xuyên tạc hay kích động.
# Comment: võ đường của sư phụ trần chân
#
# Assistant Response: KHONG_LIEN_QUAN
# Giải thích: Bình luận đề cập đến "võ đường của sư phụ trần chân", một nhân vật không liên quan đến nội dung bài đăng về các nhân vật lịch sử cứu nước. Bình luận này không thể hiện bất kỳ thái độ nào đối với nhà nước Việt Nam và hoàn toàn tách biệt khỏi chủ đề được đề cập trong bài đăng. Do đó, nó thuộc nhóm KHONG_LIEN_QUAN.
#
# Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# -----------------------------------------Sample 3:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Nhận xét về bức ảnh, cho rằng những người trong ảnh có lẽ đã lớn tuổi.
# 2. Vấn đề: Không có vấn đề chính trị rõ ràng.
# 3. Phản động/tin giả: không, nội dung mang tính chất hoài niệm về quá khứ.
# Comment: thời trai trẻ mình cũng thích mấy nàng nhưng nay đã già rồi
#
# Assistant Response: KHONG_LIEN_QUAN
# Giải thích: Bình luận đơn thuần thể hiện sự hoài niệm về tuổi trẻ và vẻ đẹp của những cô gái trong quá khứ, không chứa đựng bất kỳ thông tin sai lệch nào và cũng không có dấu hiệu chỉ trích hay chống phá chính quyền. Nội dung mang tính chất cá nhân và hoài cổ.
#
# Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# -----------------------------------------Sample 4:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Thông báo về việc bắt giữ một đối tượng khủng bố âm mưu lật đổ chính quyền.
#
# 2. Vấn đề: Thông tin về việc bắt giữ một đối tượng bị cáo buộc có hành vi khủng bố và âm mưu lật đổ chính quyền.
#
# 3. Phản động/tin giả: Có. Việc bắt giữ đối tượng khủng bố âm mưu lật đổ chính quyền là một hành động trấn áp các hoạt động chống phá nhà nước.
# Comment: khảo sát bằng hết 100 chưa và chắc là 100 là người ta nói chính xác cho không biết không
#
# Assistant Response: KHONG_LIEN_QUAN
# Giải thích: Bình luận chỉ đơn thuần đặt câu hỏi về mức độ khảo sát (100%) mà không mang tính chất xuyên tạc, bôi nhọ hay chống phá chính quyền. Nội dung ngắn gọn và không thể hiện quan điểm chính trị rõ ràng.
#
# Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# -----------------------------------------Sample 5:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Người viết, một Việt kiều đời thứ hai ở Úc, chia sẻ về trải nghiệm của gia đình sau chiến tranh, sự khác biệt văn hóa giữa Việt Nam và Úc, và những mâu thuẫn giữa các thế hệ. Người viết cũng bày tỏ sự lo lắng về việc cộng đồng người Việt ở nước ngoài bị chế nhạo và chỉ trích trên mạng xã hội.
#
# 2. Vấn đề: Sự khác biệt văn hóa giữa Việt Nam và cộng đồng người Việt ở nước ngoài, sự phân biệt đối xử mà người Việt kiều phải đối mặt, và sự chia rẽ trong cộng đồng người Việt.
#
# 3. Phản động/tin giả: Không. Bài viết chủ yếu tập trung vào trải nghiệm cá nhân và những vấn đề mà cộng đồng người Việt ở nước ngoài phải đối mặt, không trực tiếp thể hiện thái độ chống phá chính quyền.
# Comment: không quan tâm một đám trẻ bị nhồi sọ thì nói lên được gì khi bản chất bắc kỳ chó nô lệ cộng sản ai cũng biết
#
# Assistant Response: PHAN_DONG
# Giải thích: Bình luận sử dụng ngôn ngữ thù hận, công kích chế độ cộng sản và những người ủng hộ nó, gọi họ là "chó nô lệ cộng sản". Mặc dù không trực tiếp kêu gọi lật đổ chính quyền, nhưng ngôn ngữ mang tính chất chống phá và xuyên tạc chế độ.
#
# Predicted: PHAN_DONG | Actual: PHAN_DONG | ✓
#
# -----------------------------------------Sample 6:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Lời kêu gọi ủng hộ kênh YouTube và câu hỏi về việc khi nào Mỹ tin Việt cộng.
# 2. Vấn đề: Sử dụng từ ngữ miệt thị "Việt cộng" để chỉ Việt Nam, thể hiện thái độ thù địch.
# 3. Phản động/tin giả: có, sử dụng ngôn ngữ thù ghét và miệt thị để bôi nhọ Việt Nam.
# Comment: có tí nước nào không mà ve vãn ở đây
#
# Assistant Response: KHONG_LIEN_QUAN
# Giải thích: Bình luận nói về việc một quốc gia nào đó không có nước để "ve vãn ở đây", không trực tiếp liên quan đến nội dung bài đăng là lời kêu gọi ủng hộ kênh YouTube và việc sử dụng từ ngữ miệt thị "việt cộng". Bình luận này không thể hiện rõ ràng thái độ phản động đối với nhà nước Việt Nam mà có vẻ như đang nói về một vấn đề địa lý hoặc tình trạng của một quốc gia khác.
#
# Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# -----------------------------------------Sample 7:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Bài viết ca ngợi vẻ đẹp của áo dài và cờ vàng ba sọc đỏ của Việt Nam Cộng Hòa, đồng thời lên án chế độ cộng sản Việt Nam, kêu gọi lật đổ và khẳng định sự phổ biến của cờ vàng ở nước ngoài.
#
# 2. Vấn đề: Sự đàn áp của chế độ cộng sản và kêu gọi người dân đứng lên chống lại.
#
# 3. Phản động/tin giả: Có. Bài viết thể hiện rõ quan điểm chống cộng, kêu gọi lật đổ chính quyền và ca ngợi chế độ Việt Nam Cộng Hòa.
# Comment: người con gái việt nam cộng hoà dỡ thương quá cháu đẹp gái quá cháu ơi mặt áo dài có lá cờ của việt nam cộng hoà đẹp nhất trên toàn thế giới
#
# Assistant Response: PHAN_DONG
# Giải thích: Bình luận này ca ngợi vẻ đẹp của áo dài kết hợp với lá cờ của Việt Nam Cộng Hòa, một biểu tượng bị chính quyền hiện tại coi là phản động. Việc sử dụng cụm từ "việt nam cộng hoà" và việc kết hợp nó với trang phục truyền thống là hành động thể hiện sự ủng hộ đối lập với chế độ hiện tại, do đó có tính chất phản động.
#
# Predicted: PHAN_DONG | Actual: PHAN_DONG | ✓
#
# -----------------------------------------Sample 8:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Đoàn quân đội nhân dân Việt Nam chuẩn bị cho lễ duyệt binh tại Quảng trường Đỏ nhân kỷ niệm 80 năm ngày chiến thắng trong Chiến tranh Vệ quốc vĩ đại. Các giáo viên đã tổng kết, rút kinh nghiệm sau thời gian luyện tập.
#
# 2. Vấn đề: Không có vấn đề cụ thể nào được nêu ra, chỉ là thông tin về công tác chuẩn bị.
#
# 3. Phản động/tin giả: không
# Comment: chúc các chiến sĩ việt nam nhiều sức khoẻ và bình an nhé
#
# Assistant Response: KHONG_LIEN_QUAN
# Giải thích: Bình luận chúc sức khỏe và bình an cho các chiến sĩ Việt Nam, thể hiện sự tôn trọng và ủng hộ đối với quân đội. Không mang tính chất chống phá hay phản động đối với nhà nước. Đây là bình luận mang tính chất tích cực và hòa hợp với nội dung bài viết.
#
# Predicted: KHONG_LIEN_QUAN | Actual: KHONG_PHAN_DONG | ✗
#
# -----------------------------------------Sample 9:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Bài viết chỉ trích Phạm Văn Đồng vì bức ảnh được cho là thân thiện với Trung Quốc trong bối cảnh chiến tranh biên giới và việc ký văn bản liên quan đến Hoàng Sa, Trường Sa. Tác giả cáo buộc ông phản bội lại những người đã hy sinh và bán nước.
#
# 2. Vấn đề: Tính chính xác của thông tin về bức ảnh và văn bản ký kết, cũng như việc quy kết động cơ và ý nghĩa của hành động của Phạm Văn Đồng.
#
# 3. Phản động/tin giả: Có. Bài viết mang tính chất công kích, xuyên tạc lịch sử và kích động hận thù dân tộc, bôi nhọ lãnh đạo.
# Comment: ba que con thì tuổi lồn đòi lấy vợ
#
# Assistant Response: KHONG_LIEN_QUAN
# Giải thích: Bình luận "ba que con thì tuổi lồn đòi lấy vợ" sử dụng ngôn ngữ thô tục và khiếm nhã, nhưng không trực tiếp liên quan đến nội dung chính của bài viết là chỉ trích Phạm Văn Đồng về vấn đề liên quan đến Trung Quốc và Hoàng Sa, Trường Sa. Bình luận này mang tính chất cá nhân, khiêu khích và không thể hiện rõ quan điểm chính trị hay thái độ phản động đối với nhà nước Việt Nam. Do đó, nó thuộc nhóm KHONG_LIEN_QUAN.
#
# Predicted: KHONG_LIEN_QUAN | Actual: KHONG_PHAN_DONG | ✗
#
# -----------------------------------------Sample 10:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Câu hỏi về việc Việt Nam có nên khoan hồng đón nhận những người từng là người Việt Nam.
#
# 2. Vấn đề: Vấn đề về sự khoan dung và tái hòa nhập của những người Việt ở nước ngoài, đặc biệt là những người có thể có quan điểm chính trị khác biệt.
#
# 3. Phản động/tin giả: Không rõ ràng. Bản thân câu hỏi không mang tính phản động, nhưng có thể được sử dụng để kích động tranh cãi về các vấn đề chính trị nhạy cảm.
# Comment: việc học rất quan trong đó cali mỹ văn minh hiện đại vậy mà ngay lịch sử thế giới cũng không biết thì cali làm gì được trumd coi là con người ở nước mỹ
#
# Assistant Response: KHONG_LIEN_QUAN
# Giải thích: Bình luận nói về việc học và sự thiếu hiểu biết về lịch sử của người Cali, không liên quan đến nội dung bài đăng về việc khoan hồng đón nhận người Việt ở nước ngoài. Không có dấu hiệu phản động.
#
# Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# -----------------------------------------Sample 11:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Người dùng bày tỏ sự khó hiểu và thất vọng về việc Tổng thống Trump cấm các nhà ngoại giao Mỹ tham dự lễ kỷ niệm 50 năm thống nhất Việt Nam, cho rằng Mỹ nên nhớ về vai trò của mình trong chiến tranh Việt Nam và ngày 30/4 là ngày hòa bình, độc lập.
#
# 2. Vấn đề: Việc Mỹ cấm các nhà ngoại giao tham dự lễ kỷ niệm 50 năm thống nhất Việt Nam.
#
# 3. Phản động/tin giả: không, thể hiện quan điểm cá nhân về một sự kiện lịch sử và chính trị.
# Comment: ông trump háo thắng vãi lồn ra nhắc đến thua cuộc khéo còn tức hơn tụi ba gậy
#
# Assistant Response: PHAN_DONG
# Giải thích: Bình luận sử dụng ngôn ngữ thô tục ("vãi lồn") và thể hiện thái độ thù địch đối với Tổng thống Trump và những người ủng hộ ông. Mặc dù không trực tiếp công kích nhà nước Việt Nam, nhưng việc sử dụng ngôn ngữ kích động và bôi nhọ lãnh đạo nước ngoài có thể bị xem là chống phá quan hệ ngoại giao của Việt Nam với các quốc gia khác, đặc biệt khi nó liên quan đến vấn đề lịch sử nhạy cảm như chiến tranh Việt Nam. Đây là hành vi kích động thù hận và chia rẽ, đi ngược lại tinh thần hợp tác và hòa giải dân tộc mà nhà nước Việt Nam đang theo đuổi.
#
# Predicted: PHAN_DONG | Actual: KHONG_LIEN_QUAN | ✗
#
# -----------------------------------------Sample 12:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Trích đoạn bài viết về cuộc sống khó khăn của một gia đình sau 1975, với những trải nghiệm đau thương như bị gọi là "con ngụy" và bạo hành.
# 2. Vấn đề: Phản ánh những khó khăn và bất công sau 1975, có thể gây tranh cãi về cách nhìn nhận lịch sử.
# 3. Phản động/tin giả: có, vì sử dụng từ ngữ miệt thị "ngụy" và mô tả những hành động bạo lực, có thể gây kích động và chia rẽ.
# Comment: kẻ thắng thì quên hận thù lâu rồi kẻ thua thì vừa phóng đại vừa nhai đi nhai lại như bò
#
# Assistant Response: KHONG_PHAN_DONG
# Giải thích: Bình luận chỉ ra sự khác biệt trong cách nhìn nhận lịch sử giữa người thắng và người thua, không trực tiếp thể hiện thái độ chống phá chính quyền mà tập trung vào việc phân tích tâm lý con người trong bối cảnh chiến tranh và hòa giải dân tộc. Không sử dụng ngôn ngữ thù hận hay kêu gọi lật đổ chế độ.
#
# Predicted: KHONG_PHAN_DONG | Actual: KHONG_PHAN_DONG | ✓
#
# -----------------------------------------Sample 13:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Câu hỏi về việc Việt Nam có nên khoan hồng đón nhận những người từng là người Việt Nam.
#
# 2. Vấn đề: Vấn đề về sự khoan dung và tái hòa nhập của những người Việt ở nước ngoài, đặc biệt là những người có thể có quan điểm chính trị khác biệt.
#
# 3. Phản động/tin giả: Không rõ ràng. Bản thân câu hỏi không mang tính phản động, nhưng có thể được sử dụng để kích động tranh cãi về các vấn đề chính trị nhạy cảm.
# Comment: ai bị treo tiền nhắn tin em chỉ chỗ làm lấy tiền lại nha em cũng mới nhân tiền về hôm qua
#
# Assistant Response: KHONG_LIEN_QUAN
# Giải thích: Bình luận này nói về việc treo tiền và yêu cầu liên hệ để lấy lại tiền, không liên quan đến nội dung chính của bài đăng về sự khoan dung đối với người Việt ở nước ngoài hoặc các vấn đề chính trị. Nó hoàn toàn tách biệt và không mang tính chất phản động.
#
# Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# -----------------------------------------Sample 14:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Bài viết kể về cuộc sống sung túc của một gia đình ở miền Nam trước năm 1975, sau đó bị đảo lộn do 'giải phóng'. Tác giả bày tỏ sự tiếc nuối và đau khổ về những mất mát mà gia đình và đồng bào phải chịu đựng.
#
# 2. Vấn đề: Tính chủ quan trong việc đánh giá về giai đoạn lịch sử. Mặc dù thể hiện nỗi đau cá nhân, nhưng có thể bị lợi dụng để xuyên tạc lịch sử.
#
# 3. Phản động/tin giả: Có thể. Mặc dù bài viết chủ yếu thể hiện nỗi đau cá nhân, nhưng việc tập trung vào những mất mát và sử dụng ngôn ngữ gợi nhớ về một 'hòn ngọc viễn đông' có thể bị lợi dụng để xuyên tạc lịch sử và kích động tâm lý chống đối.
# Comment: xem con chó vừa chửi ông bà các cụ nó là mọi nói gì kìa
#
# Assistant Response: KHONG_LIEN_QUAN
# Giải thích: Bình luận "xem con chó vừa chửi ông bà các cụ nó là mọi nói gì kìa" sử dụng ngôn ngữ thô tục và chỉ trích cá nhân, nhưng không trực tiếp liên quan đến nội dung chính của bài viết về nỗi đau và mất mát do 'giải phóng'. Bình luận này mang tính chất bôi nhọ và công kích cá nhân, tuy nhiên không thể hiện rõ ràng quan điểm phản động đối với nhà nước Việt Nam. Nó có thể là phản ứng tức giận đối với một ý kiến nào đó trong thread, nhưng không trực tiếp thể hiện thái độ chống phá chế độ. Do đó, bình luận này thuộc nhóm KHONG_LIEN_QUAN vì không trực tiếp thể hiện quan điểm chính trị trái chiều với nhà nước.
#
# Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# -----------------------------------------Sample 15:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Bài viết thể hiện sự căm ghét đối với 'cộng sản', cho rằng họ 'cay cú' vì những lời than phiền và vẫn giữ sự 'mọi rợ' như thời xưa.
#
# 2. Vấn đề: Chỉ trích và bôi nhọ chế độ cộng sản.
#
# 3. Phản động/tin giả: Có. Sử dụng ngôn ngữ thù hận, xuyên tạc lịch sử và bôi nhọ chế độ.
# Comment: luật nào cấm dân than phiền luật bắc chó cộng cộng sản có có bộ luật rừng tự viết tự sửa đéo cấm mà con mc bị đấu tố đó thằng ngu lồn trên reddit các bác nhà mày đéo động được thôi động được thì khác gì cái ổ chó facebook làm phiền thì nó nói làm phiền nó phạm luật gì bọn đấu tố con mc cũng là chó của lũ tuyên giáo thả ra lòe lũ bò con học sinh cấp hai cấp ba lũ patek ăn hại giỏi hà hiếp người cô thế thôi làm cái cầu phao giúp dân 28 ngày mới xong mà diễu binh làm phiền dân thì rầm rộ thấy ớn nó nói tiếng chó mà chúng mày cũng hiểu được à úi xin lỗi tôi lỡ hiểu tiếng chó rồibằng viết cái tên riêng cũng sai ngu ngục thế là cùng chó ngoan của việt cộng súc vật nô lệ của tàu cộng có khác mày đúng là sản phẩm của cái trại súc vật việt cộng đéo biết cãi bằng lý lẽ chỉ biết sủa những câu đã được bơm sẵn vào đầu gặp ai cũng ẳng nhưng câu đó lặp đi lặp lại đúng chuẩn chó ngoan béc hù sủa ngu rồi bảo không lý lẽ quả là phế phẩm của nền giáo dục nhồi sọ súc vật nô lệ của tàu cộng
#
# Assistant Response: PHAN_DONG
# Giải thích: Bình luận sử dụng ngôn ngữ thù hận, công kích chế độ cộng sản và chính quyền Việt Nam, gọi chế độ là "việt cộng", "súc vật nô lệ của tàu cộng". Đồng thời, bình luận này chỉ trích nền giáo dục và chế độ chính trị, thể hiện thái độ chống phá và thù ghét chế độ hiện tại. Những yếu tố này rõ ràng mang tính chất phản động đối với nhà nước Việt Nam.
#
# Predicted: PHAN_DONG | Actual: PHAN_DONG | ✓
#
# -----------------------------------------Sample 16:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Người dùng so sánh bà Nguyễn Thị Bình (Madam Bình) trong quá khứ và hiện tại, ám chỉ việc bà có mối quan hệ với những người thuộc 'ba que hải phòng'.
#
# 2. Vấn đề: Sự thay đổi hoặc mối quan hệ của bà Nguyễn Thị Bình với một nhóm người bị coi là tiêu cực.
#
# 3. Phản động/tin giả: có, sử dụng ngôn ngữ miệt thị ('ba que') và ám chỉ tiêu cực về một nhân vật lịch sử.
# Comment: nguy hiểm quá yêu nước nhưng cũng để ý an toàn bản thân chứ xem mà cứ sợ chị bị làm sao
#
# Assistant Response: KHONG_LIEN_QUAN
# Giải thích: Bình luận bày tỏ lo lắng về sự an toàn của một người được nhắc đến trong bài đăng, không trực tiếp thể hiện quan điểm chính trị hay thái độ chống phá nhà nước Việt Nam. Dù nội dung liên quan đến một nhân vật lịch sử nhưng bình luận này tập trung vào cảm xúc cá nhân và không mang tính chất xuyên tạc hay kích động.
#
# Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# -----------------------------------------Sample 17:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Trích đoạn bài viết về cuộc sống khó khăn của một gia đình sau 1975, với những trải nghiệm đau thương như bị gọi là "con ngụy" và bạo hành.
# 2. Vấn đề: Phản ánh những khó khăn và bất công sau 1975, có thể gây tranh cãi về cách nhìn nhận lịch sử.
# 3. Phản động/tin giả: có, vì sử dụng từ ngữ miệt thị "ngụy" và mô tả những hành động bạo lực, có thể gây kích động và chia rẽ.
# Comment: bô nhà tao thì tao bê chả lẽ tao bê bô mĩ
#
# Assistant Response: KHONG_LIEN_QUAN
# Giải thích: Bình luận sử dụng từ ngữ thô tục và không liên quan đến nội dung chính của bài viết về những khó khăn sau năm 1975. Nó thể hiện sự thiếu tôn trọng và không mang tính chất phản động đối với nhà nước Việt Nam.
#
# Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# -----------------------------------------Sample 18:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Bộ trưởng Thương mại Mỹ cho rằng Việt Nam là trạm trung chuyển hàng hóa Trung Quốc sang Mỹ để tránh thuế, đe dọa dỡ bỏ ưu đãi thương mại cho Việt Nam.
# 2. Vấn đề: Quan hệ thương mại Việt Nam - Mỹ, sự phụ thuộc của Việt Nam vào chuỗi cung ứng Trung Quốc.
# 3. Phản động/tin giả: không
# Comment: hóa ra cũng chỉ vì tiền
#
# Assistant Response: KHONG_LIEN_QUAN
# Giải thích: Bình luận "hóa ra cũng chỉ vì tiền" đơn thuần thể hiện sự thấu hiểu về động cơ kinh tế trong quan hệ thương mại, không mang bất kỳ nội dung chống phá hay phản động nào đối với nhà nước Việt Nam. Nó chỉ là một nhận xét ngắn gọn về bản chất của các hoạt động thương mại quốc tế.
#
# Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# -----------------------------------------Sample 19:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Thông báo về việc bắt giữ một đối tượng khủng bố âm mưu lật đổ chính quyền.
#
# 2. Vấn đề: Thông tin về việc bắt giữ một đối tượng bị cáo buộc có hành vi khủng bố và âm mưu lật đổ chính quyền.
#
# 3. Phản động/tin giả: Có. Việc bắt giữ đối tượng khủng bố âm mưu lật đổ chính quyền là một hành động trấn áp các hoạt động chống phá nhà nước.
# Comment: cái pha còn ngông lắm các anh giúp cụp cái pha xuống đi ạ
#
# Assistant Response: KHONG_LIEN_QUAN
# Giải thích: Bình luận sử dụng từ ngữ "cụp cái pha xuống" mang tính chất châm biếm, tuy nhiên không trực tiếp thể hiện quan điểm chống phá hay phản động đối với nhà nước. Nội dung ngắn gọn và không rõ ràng về mục đích, có thể chỉ là một câu nói đùa hoặc thể hiện sự bất mãn cá nhân nào đó nhưng không liên quan trực tiếp đến vấn đề chính trị hay chế độ. Do đó, không đủ cơ sở để xếp vào nhóm PHAN_DONG.
#
# Predicted: KHONG_LIEN_QUAN | Actual: KHONG_PHAN_DONG | ✗
#
# -----------------------------------------Sample 20:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Khen ngợi vẻ đẹp của những người mặc áo vàng ba sọc đỏ (ám chỉ cờ của Việt Nam Cộng Hòa).
#
# 2. Vấn đề: Ca ngợi chế độ cũ, có thể gây chia rẽ.
#
# 3. Phản động/tin giả: có, thể hiện sự ủng hộ chế độ Việt Nam Cộng Hòa, đi ngược lại quan điểm của chính phủ hiện tại.
# Comment: thật ra những người miền bắc cũng là nạn nhân của tàu cộng và họ khô hơn người miền nam nhiều lắm nếu tất cả những người việt nam nhìn ra được thì mới có thể cứu được nhưng tiếc rằng giới trẻ việt nam đã bị nhồi sọ và đầu độc nặng lắm rồi hết thuốc chữa
#
# Assistant Response: PHAN_DONG
# Giải thích: Bình luận công nhận sự tồn tại của "Việt Nam Cộng Hòa" (áo vàng ba sọc đỏ) và ca ngợi vẻ đẹp của nó, đồng thời chỉ trích "tàu cộng" và cho rằng giới trẻ Việt Nam bị "nhồi sọ" bởi chính quyền hiện tại. Những hành động này thể hiện sự phản đối chế độ hiện tại và ủng hộ một chế độ thay thế, đi ngược lại quan điểm của chính phủ Việt Nam.
#
# Predicted: PHAN_DONG | Actual: PHAN_DONG | ✓
#
# -----------------------------------------Sample 21:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Văn bản chỉ có một từ "Bò Đỏ".
# 2. Vấn đề: Sử dụng biệt ngữ chính trị để chỉ người ủng hộ Đảng Cộng sản một cách chế giễu.
# 3. Phản động/tin giả: không, chỉ là một từ mang tính chế giễu.
# Comment: nó đu càng lâu rồi
#
# Assistant Response: KHONG_LIEN_QUAN
# Giải thích: Bình luận "nó đu càng lâu rồi" không trực tiếp thể hiện quan điểm chính trị hay phản động. Đây là một câu nói mang tính chất cá nhân, có thể liên quan đến ngữ cảnh nào đó nhưng không rõ ràng và không thể hiện sự chống phá hay bất đồng với nhà nước Việt Nam. Do đó, nó thuộc nhóm "KHONG_LIEN_QUAN".
#
# Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# -----------------------------------------Sample 22:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Người dùng đặt câu hỏi về vai trò của nhà nước trong việc giúp đỡ người nghèo, cho rằng nhà nước nên sử dụng tiền từ các công trình xây dựng không cần thiết để hỗ trợ người dân.
#
# 2. Vấn đề: Sự bất bình về việc nhà nước đầu tư vào các công trình lớn trong khi người nghèo không nhận được sự giúp đỡ tương xứng.
#
# 3. Phản động/tin giả: không. Mặc dù có lời lẽ gay gắt, nhưng nội dung chủ yếu thể hiện sự bất mãn với chính sách xã hội, không trực tiếp kêu gọi lật đổ hay chống phá nhà nước.
# Comment: nhồi sọ và tận thu dân đen để nuôi dưỡng giai cấp đảng cộng sản việt nam
#
# Assistant Response: PHAN_DONG
# Giải thích: Bình luận sử dụng ngôn ngữ thô tục và kích động, trực tiếp chỉ trích chế độ chính trị và "tận thu dân đen" để phục vụ lợi ích riêng của "giai cấp đảng cộng sản". Dù không nêu rõ mục đích cụ thể nhưng ngôn ngữ mang tính chất chống phá và bôi nhọ chế độ chính trị hiện tại.
#
# Predicted: PHAN_DONG | Actual: PHAN_DONG | ✓
#
# -----------------------------------------Sample 23:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Đề cập đến danh sách nhân viên 3 goe, có thể liên quan đến một tổ chức hoặc nhóm người nào đó.
#
# 2. Vấn đề: Không rõ mục đích, có thể là bôi nhọ, công kích cá nhân hoặc tổ chức.
#
# 3. Phản động/tin giả: có, nếu thông tin sai lệch hoặc nhằm mục đích bôi nhọ, gây chia rẽ.
# Comment: quan trọng người ta có hoạt động chống phá không hay chỉ hát không đính liếu tới chính trị gì cả
#
# Assistant Response: KHONG_LIEN_QUAN
# Giải thích: Bình luận này đặt câu hỏi về tính chất hoạt động của một nhóm/người, nhưng không trực tiếp thể hiện quan điểm phản động hay ủng hộ chính quyền. Nó mang tính chất trung lập, yêu cầu làm rõ vấn đề thay vì thể hiện thái độ chính trị rõ ràng.
#
# Predicted: KHONG_LIEN_QUAN | Actual: KHONG_PHAN_DONG | ✗
#
# -----------------------------------------Sample 24:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Bài viết tố cáo Đảng Cộng sản Việt Nam đã lừa dối người dân bằng cách lợi dụng lòng yêu nước, sự thiếu hiểu biết để phục vụ mục đích riêng. Các chiêu trò được liệt kê bao gồm: sử dụng trẻ em trong chiến tranh, trốn trong nhà dân gây nguy hiểm cho dân thường, lợi dụng sự ngu dốt của dân để cướp đất, cướp của, và tuyên truyền thù hận, chia rẽ dân tộc.
#
# 2. Vấn đề: Bài viết tập trung vào việc tố cáo sự lừa dối và những hành động bị cho là tàn bạo của Đảng Cộng sản Việt Nam trong quá khứ và hiện tại.
#
# 3. Phản động/tin giả: Có. Bài viết sử dụng ngôn ngữ kích động, bôi nhọ, xuyên tạc lịch sử và chế độ hiện tại, nhằm mục đích gây chia rẽ và bất mãn trong xã hội.
# Comment: cộng sản nó sinh ra để làm những điều kinh khủng với dân nói chung cũng chẳng khác gì cái bọn phát xít độc tài chẳng hạn
#
# Assistant Response: PHAN_DONG
# Giải thích: Bình luận trực tiếp bôi nhọ và so sánh Đảng Cộng sản Việt Nam với các chế độ phát xít độc tài, sử dụng ngôn ngữ kích động và xuyên tạc lịch sử để công kích chính quyền. Nội dung thể hiện rõ thái độ chống phá và phủ nhận vai trò của chế độ hiện tại.
#
# Predicted: PHAN_DONG | Actual: PHAN_DONG | ✓
#
# -----------------------------------------Sample 25:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Một người ăn hết 100 cuốn chả giò.
#
# 2. Vấn đề: Không rõ mục đích, có thể là thử thách hoặc khoe khoang.
#
# 3. Phản động/tin giả: không, nội dung vô thưởng vô phạt.
# Comment: ông trump ổng trục xuất là không biết đi đâu
#
# Assistant Response: KHONG_LIEN_QUAN
# Giải thích: Bình luận nói về việc ông Trump trục xuất ai đó và người bị trục xuất không biết đi đâu, nhưng không trực tiếp liên quan đến nội dung bài đăng về việc ăn 100 cuốn chả giò. Bình luận này cũng không mang tính chất phản động đối với nhà nước Việt Nam.
#
# Predicted: KHONG_LIEN_QUAN | Actual: KHONG_PHAN_DONG | ✗
#
# -----------------------------------------Sample 26:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Bài viết chỉ trích lễ kỷ niệm 50 năm ngày 30/4/2025 của Đảng Cộng sản Việt Nam, cho rằng sự kiện này tốn kém, phô trương và gây ra nhiều hình ảnh tiêu cực, phản cảm.
#
# 2. Vấn đề: Sự lãng phí, hình thức và những sai sót trong tổ chức lễ kỷ niệm 50 năm ngày 30/4, cùng với việc sử dụng tiền thuế của dân không hiệu quả.
#
# 3. Phản động/tin giả: Có. Bài viết thể hiện quan điểm chống chính quyền, chỉ trích Đảng Cộng sản Việt Nam và chế độ hiện tại.
# Comment: page này bán thì có chia không hay đưa vào ngân khố để trả nợ nghe đâu kí giấy nợ gì gì mấy ngàn đô thì phải
#
# Assistant Response: KHONG_LIEN_QUAN
# Giải thích: Bình luận tập trung vào việc nghi vấn về nguồn gốc tài chính của page và khả năng bị bán, không trực tiếp thể hiện quan điểm chống phá chính quyền hay phủ nhận sự thật lịch sử như các nội dung phản động thường làm. Mặc dù có tính chất hoài nghi nhưng chưa vượt quá giới hạn của sự tranh luận chính trị bình thường.
#
# Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# -----------------------------------------Sample 27:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Bài viết ca ngợi vẻ đẹp của áo dài và cờ vàng ba sọc đỏ của Việt Nam Cộng Hòa, đồng thời lên án chế độ cộng sản Việt Nam, kêu gọi lật đổ và khẳng định sự phổ biến của cờ vàng ở nước ngoài.
#
# 2. Vấn đề: Sự đàn áp của chế độ cộng sản và kêu gọi người dân đứng lên chống lại.
#
# 3. Phản động/tin giả: Có. Bài viết thể hiện rõ quan điểm chống cộng, kêu gọi lật đổ chính quyền và ca ngợi chế độ Việt Nam Cộng Hòa.
# Comment: úi bóng ma ngỏm 50 năm rồi mà chưa siêu thoát tầm bậy còn thiếu hồn ma diệm nhu thiệu và đám đệ tử
#
# Assistant Response: KHONG_PHAN_DONG
# Giải thích: Bình luận sử dụng ngôn ngữ

#
# Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# -----------------------------------------Sample 31:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Bài viết ca ngợi vẻ đẹp của áo dài và cờ vàng ba sọc đỏ của Việt Nam Cộng Hòa, đồng thời lên án chế độ cộng sản Việt Nam, kêu gọi lật đổ và khẳng định sự phổ biến của cờ vàng ở nước ngoài.
#
# 2. Vấn đề: Sự đàn áp của chế độ cộng sản và kêu gọi người dân đứng lên chống lại.
#
# 3. Phản động/tin giả: Có. Bài viết thể hiện rõ quan điểm chống cộng, kêu gọi lật đổ chính quyền và ca ngợi chế độ Việt Nam Cộng Hòa.
# Comment: chúng mày chỉ là một lũ ăn cứt còn mấy thằng già sắp chết cũng đòi chống cộng
#
# Assistant Response: PHAN_DONG
# Giải thích: Bình luận sử dụng ngôn ngữ miệt thị ("ăn cứt") và trực tiếp thể hiện thái độ thù địch đối với những người chống cộng, đặc biệt là những người ủng hộ chế độ Việt Nam Cộng Hòa được đề cập trong bài viết. Mặc dù không trực tiếp kêu gọi lật đổ chính quyền, nhưng việc công kích những người có quan điểm khác và sử dụng ngôn ngữ thô tục thể hiện tư tưởng phản động đối với các quan điểm chính trị đối lập.
#
# Predicted: PHAN_DONG | Actual: KHONG_PHAN_DONG | ✗
#
# -----------------------------------------Sample 32:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Bài viết cho rằng Putin cố tình sắp xếp cho Tô Lâm và Maduro ngồi cạnh nhau để nhắc lại vụ ăn bò dát vàng gây tranh cãi của cả hai.
# 2. Vấn đề: Bêu riếu Tô Lâm và Maduro về hành vi xa hoa trong khi dân chúng gặp khó khăn.
# 3. Phản động/tin giả: Có, bài viết sử dụng ngôn ngữ mỉa mai, châm biếm, và có thể mang tính xuyên tạc về động cơ của Putin, nhằm mục đích hạ uy tín lãnh đạo Việt Nam.
# Comment: ông cố nội cha nó cũng không dám về nữa nói chi nó
#
# Assistant Response: KHONG_LIEN_QUAN
# Giải thích: Bình luận "ông cố nội cha nó cũng không dám về nữa nói chi nó" sử dụng ngôn ngữ thô tục và cá nhân hóa để chỉ trích một người nào đó (có thể là ông Tô Lâm). Mặc dù có tính chất công kích cá nhân, nhưng bình luận này không trực tiếp thể hiện quan điểm chống phá nhà nước Việt Nam mà tập trung vào việc bôi nhọ danh dự cá nhân. Do đó, nó thuộc nhóm KHONG_LIEN_QUAN vì không rõ ràng thể hiện quan điểm chính trị chống đối.
#
# Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# -----------------------------------------Sample 33:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Khen ngợi vẻ đẹp của những người mặc áo vàng ba sọc đỏ (ám chỉ cờ của Việt Nam Cộng Hòa).
#
# 2. Vấn đề: Ca ngợi chế độ cũ, có thể gây chia rẽ.
#
# 3. Phản động/tin giả: có, thể hiện sự ủng hộ chế độ Việt Nam Cộng Hòa, đi ngược lại quan điểm của chính phủ hiện tại.
# Comment: lũ chúng nó bị nhồi sọ từ trong trứng đầu óc bá đậu của chúng chứa đựng lòng hận thù mà mối hận này là do cha ông chúng nó gây ra chúng rước giặc về thờ làm anh em đồng chí sáu vàng bốn tốt chính chúng nó ký công hàm bán nước cho giặc dâng hoàng sa trường sa cho anh em đồng chí của chúng ải nam quan thác bản giốc 200 000 km2 vùng lãnh hải vịnh bắc bộ ngày nay thuộc về giặc tc là người anh em đồng chí tám vàng bốn tốt của chúng
#
# Assistant Response: KHONG_PHAN_DONG
# Giải thích: Bình luận sử dụng ngôn ngữ thô t
predicted: PHAN_DONG | Actual: KHONG_LIEN_QUAN | ✗
#
# -----------------------------------------Sample 39:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Ảnh Sài Gòn năm 1973 với lượng xe máy ít hơn hiện nay, mời xem thêm ảnh đẹp ở phần bình luận.
# 2. Vấn đề: Không có vấn đề chính trị rõ ràng.
# 3. Phản động/tin giả: không, nội dung mang tính chất hoài niệm về quá khứ.
# Comment: nội chiến thứ ngi i im mồm đi cào nail bưng phở đi chả có cuộc nội chiến nào
#
# Assistant Response: KHONG_LIEN_QUAN
# Giải thích: Bình luận sử dụng từ ngữ thô tục ("cào nail") và thể hiện sự bất mãn với việc người khác nhắc đến nội chiến, nhưng không trực tiếp thể hiện quan điểm chống phá hay phản động đối với nhà nước Việt Nam. Nội dung chủ yếu là chỉ trích cách hành xử của người khác trong cuộc trò chuyện.
#
# Predicted: KHONG_LIEN_QUAN | Actual: KHONG_PHAN_DONG | ✗
#
# -----------------------------------------Sample 40:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Trích đoạn bài viết về cuộc sống khó khăn của một gia đình sau 1975, với những trải nghiệm đau thương như bị gọi là "con ngụy" và bạo hành.
# 2. Vấn đề: Phản ánh những khó khăn và bất công sau 1975, có thể gây tranh cãi về cách nhìn nhận lịch sử.
# 3. Phản động/tin giả: có, vì sử dụng từ ngữ miệt thị "ngụy" và mô tả những hành động bạo lực, có thể gây kích động và chia rẽ.
# Comment: thế mày gốc khomer hay tàu thế
#
# Assistant Response: KHONG_LIEN_QUAN
# Giải thích: Bình luận hỏi về nguồn gốc dân tộc của người được nhắc đến trong bài viết, nhưng không trực tiếp thể hiện thái độ phản động hay ủng hộ chính quyền. Nó đơn thuần là một câu hỏi về thông tin cá nhân và không mang tính chất chống phá nhà nước.
#
# Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# -----------------------------------------Sample 41:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Văn bản chỉ có một từ "Bò Đỏ".
# 2. Vấn đề: Sử dụng biệt ngữ chính trị để chỉ người ủng hộ Đảng Cộng sản một cách chế giễu.
# 3. Phản động/tin giả: không, chỉ là một từ mang tính chế giễu.
# Comment: thế hệ kế thừa đám phản quốc ba que đu càng vẫn y như cha ông chúng nó nhỉ chó vện sinh ra chó không thể hơn được tưởng đâu qua mỹ rồi cái gen được cải tiến chớ ai dè chán thật
#
# Assistant Response: PHAN_DONG
# Giải thích: Bình luận sử dụng ngôn ngữ miệt thị ("chó vện", "phản quốc") để công kích những người ủng hộ chính quyền hiện tại, thể hiện thái độ thù địch với chế độ và có xu hướng xuyên tạc lịch sử về những người di cư sang Mỹ. Mặc dù không trực tiếp kêu gọi lật đổ, nhưng ngôn ngữ thù hận và xuyên tạc này mang tính chất chống phá chính quyền.
#
# Predicted: PHAN_DONG | Actual: KHONG_PHAN_DONG | ✗
#
# -----------------------------------------Sample 42:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Dân biểu Derek Trần tổ chức hội luận với cộng đồng gốc Việt về các giải pháp thúc đẩy cải thiện tình hình nhân quyền và xã hội dân sự tại Việt Nam. Dân biểu Judy Chu và Grace Meng cũng tham dự, thể hiện sự quan tâm của các nhà lập pháp Hoa Kỳ đối với vấn đề này. Sự kiện này là một trong ba sự kiện tưởng niệm 50 năm 'biến cố tháng tư đen'.
#
# 2. Vấn đề: Tình hình nhân quyền và xã hội dân sự tại Việt Nam, và sự quan tâm của các nhà lập pháp Hoa Kỳ.
#
# 3. Phản động/tin giả: Có. Việc sử dụng cụm từ 'biến cố tháng tư đen' và việc các dân biểu Hoa Kỳ can thiệp vào vấn đề nội bộ của Việt Nam có thể được xem là phản động.
# Comment: ai mượn tham gia vào
#
# Assistant Response: KHONG_LIEN_QUAN
# Giải thích: Bình luận "ai mượn tham gia vào" rất ngắn gọn và không mang bất kỳ thông tin hay ý nghĩa rõ ràng nào liên quan đến nội dung bài đăng về hội luận của dân biểu Derek Trần và các vấn đề nhân quyền tại Việt Nam. Nó không thể hiện thái độ ủng hộ hay chống đối chế độ mà chỉ là một câu hỏi mơ hồ, không có tính chất chính trị. Do đó, nó thuộc nhóm KHONG_LIEN_QUAN.
#
# Predicted: KHONG_LIEN_QUAN | Actual: KHONG_PHAN_DONG | ✗
#
# -----------------------------------------Sample 43:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Bài viết chỉ trích lễ kỷ niệm 50 năm ngày 30/4/2025 của Đảng Cộng sản Việt Nam, cho rằng sự kiện này tốn kém, phô trương và gây ra nhiều hình ảnh tiêu cực, phản cảm.
#
# 2. Vấn đề: Sự lãng phí, hình thức và những sai sót trong tổ chức lễ kỷ niệm 50 năm ngày 30/4, cùng với việc sử dụng tiền thuế của dân không hiệu quả.
#
# 3. Phản động/tin giả: Có. Bài viết thể hiện quan điểm chống chính quyền, chỉ trích Đảng Cộng sản Việt Nam và chế độ hiện tại.
# Comment: việt tân không bằng mấy con chó của mấy chú bộ đội ngồi không sủa hoài vậy
#
# Assistant Response: KHONG_PHAN_DONG
# Giải thích: Bình luận sử dụng ngôn ngữ thô tục để bôi nhọ và công kích những người có quan điểm khác (trong trường hợp này là Việt Tân). Mặc dù có tính chất thù hận, nhưng nó không trực tiếp thể hiện quan điểm chống phá chính quyền hay chế độ hiện tại mà tập trung vào việc công kích cá nhân hoặc nhóm đối tượng cụ thể. Do đó, bình luận này thuộc nhóm không phản động.
#
# Predicted: KHONG_PHAN_DONG | Actual: KHONG_PHAN_DONG | ✓
#
# -----------------------------------------Sample 44:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Bài viết phản hồi về một bài đăng than vãn về sự vất vả khi làm việc ở nước ngoài. Người viết cho rằng việc vất vả là điều hiển nhiên khi làm việc ở nước ngoài và mỉa mai việc than vãn đi kèm với sự tự hào về Việt Nam.
#
# 2. Vấn đề: Bài viết thể hiện sự phản đối việc than vãn về khó khăn khi làm việc ở nước ngoài, cho rằng đó là điều hiển nhiên và không đáng để phàn nàn.
#
# 3. Phản động/tin giả: Không. Bài viết thể hiện quan điểm cá nhân về một vấn đề xã hội, không có dấu hiệu xuyên tạc, bôi nhọ hay chống phá.
# Comment: giờ vẫn còn tin bị đuổi ra khỏi nhà thì hiểu tư duy của mày rồi ở việt nam thì không bị đuổi đâu chỉ bị cưỡng chế đất thôi còn tao chưa thấy cơm thừa canh cặn bao giờ chỉ thấy sinh viên bk hà nội được ăn thứ mà mày nói thôi
#
# Assistant Response: PHAN_DONG
# Giải thích: Bình luận sử dụng ngôn ngữ thô tục ("cơm thừa canh cặn") và công kích cá nhân ("sinh viên bk hà nội") để chỉ trích những người ủng hộ chính quyền. Việc gọi người khác là "đồ ăn xong" và ám chỉ việc cưỡng chế đất đai là sai trái thể hiện thái độ chống đối chính sách của nhà nước. Mặc dù không trực tiếp kêu gọi lật đổ, nhưng ngôn ngữ thù hận và công kích chế độ là dấu hiệu của tư tưởng phản động.
#
# Predicted: PHAN_DONG | Actual: KHONG_LIEN_QUAN | ✗
#
# -----------------------------------------Sample 45:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Đề cập đến danh sách nhân viên 3 goe, có thể liên quan đến một tổ chức hoặc nhóm người nào đó.
#
# ...
#
# 3. Phản động/tin giả: Có thể có. Nếu thông tin sai sự thật hoặc được sử dụng để gây hoang mang, kích động.
# Comment: bọn ba que tụi mày cứ khát nước tiếp đikhát hết cổ họng cũng không có nước đâu
#
# Assistant Response: PHAN_DONG
# Giải thích: Bình luận sử dụng ngôn ngữ thô tục ("ba que") và có ý nghĩa công kích, châm biếm về khả năng tiếp cận thông tin của một nhóm người, ngụ ý rằng họ bị hạn chế quyền lợi và sự thật. Điều này thể hiện thái độ chống đối và chỉ trích chế độ.
#
# Predicted: PHAN_DONG | Actual: KHONG_PHAN_DONG | ✗
#
# -----------------------------------------Sample 197:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Người viết chia sẻ trải nghiệm tiêu cực khi làm căn cước công dân và khi em trai bị mất xe, cho rằng tiền bạc có thể khiến con người trở nên 'thối rữa'.
#
# 2. Vấn đề: Tham nhũng, hối lộ trong thủ tục hành chính và sự bất lực trước tội phạm.
#
# 3. Phản động/tin giả: Không. Mặc dù chỉ trích tiêu cực, nhưng dựa trên trải nghiệm cá nhân và không có dấu hiệu xuyên tạc hoặc kích động bạo lực.
# Comment: hàng xóm đối diện nhà tôi là hai ông bà già 70t bị trộm viếng mất tầm vài chục củ cộng mấy cây vàng công an kéo tới lập biên bản chụp ảnh lấy vân tay xong cũng gợi ý nhà hai ông bà già kia cũng phong bì vài củ tới nay là năm năm trôi qua nhà kia vẫn không thấy số tiền mất của mình đâu
#
# Assistant Response: KHONG_PHAN_DONG
# Giải thích: Bình luận kể về trường hợp hàng xóm bị trộm và công an gợi ý phong bì, thể hiện sự bất mãn về cách xử lý của cơ quan chức năng. Tuy nhiên, nội dung chủ yếu tập trung vào mô tả sự việc và bày tỏ sự thất vọng cá nhân, không trực tiếp thể hiện thái độ chống phá hay phủ nhận chính quyền. Trong khi đó, những vấn đề được nhắc đến (như tham nhũng) tuy tiêu cực nhưng không mang tính chất kích động lật đổ hay chống phá chế độ. Do đó, bình luận này thuộc nhóm KHÔNG_LIÊN_QUAN. Sửa lại: KHÔNG_LIÊN_QUAN thành KHONG_LIÊN_QUAN đã đúng. Nội dung chỉ đơn thuần mô tả sự việc và bày tỏ sự bất mãn cá nhân, không có dấu hiệu xuyên tạc hay kích động bạo lực. Có thể có ý nghĩa tiêu cực về mặt xã hội, nhưng không đủ điều kiện để xếp vào nhóm PHẢN_ĐỘNG. Do đó, đáp án KHONG_LIÊN_QUAN là phù hợp.
#
# Predicted: KHONG_PHAN_DONG | Actual: KHONG_PHAN_DONG | ✓
#
# -----------------------------------------Sample 198:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Văn bản chỉ có một từ "Bò Đỏ".
# 2. Vấn đề: Sử dụng biệt ngữ chính trị để chỉ người ủng hộ Đảng Cộng sản một cách chế giễu.
# 3. Phản động/tin giả: không, chỉ là một từ mang tính chế giễu.
# Comment: bò đỏ này xuất xứ từ đâu ra vậy ta
#
# Assistant Response: KHONG_LIEN_QUAN
# Giải thích: Bình luận hỏi về nguồn gốc của cụm từ "bò đỏ" mà không trực tiếp thể hiện thái độ chống phá hay ủng hộ chính quyền. Mặc dù sử dụng biệt ngữ chế giễu nhưng câu hỏi này không mang tính chất tuyên truyền hay kích động chống đối.
#
# Predicted: KHONG_LIEN_QUAN | Actual: KHONG_PHAN_DONG | ✗
#
# -----------------------------------------Sample 199:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Động đất và cháy rừng được cho là do cộng sản gây ra.
#
# 2. Vấn đề: Lan truyền thông tin sai lệch, đổ lỗi cho cộng sản về thiên tai.
#
# 3. Phản động/tin giả: Có. Đổ lỗi cho cộng sản về thiên tai là hành vi tuyên truyền sai sự thật, có thể gây hoang mang dư luận và kích động thù hằn.
# Comment: giống té giếng hay sao nhỉ
#
# Assistant Response: KHONG_LIEN_QUAN
# Giải thích: Bình luận "giống té giếng hay sao nhỉ" sử dụng một thành ngữ tiếng Việt để chỉ việc đổ lỗi cho người khác khi gặp khó khăn. Trong ngữ cảnh này, nó ám chỉ việc đổ lỗi cho cộng sản về các vấn đề như động đất và cháy rừng. Tuy nhiên, bình luận này ngắn gọn và không trực tiếp thể hiện quan điểm chính trị rõ ràng, cũng không trực tiếp công kích hay chống phá chính quyền. Do đó, nó được xếp vào nhóm không liên quan vì thiếu yếu tố trực tiếp thể hiện thái độ phản động đối với nhà nước Việt Nam.
#
# Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# -----------------------------------------Sample 200:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Văn bản chỉ có một từ "Bò Đỏ".
# 2. Vấn đề: Sử dụng biệt ngữ chính trị để chỉ người ủng hộ Đảng Cộng sản một cách chế giễu.
# 3. Phản động/tin giả: không, chỉ là một từ mang tính chế giễu.
# Comment: bạn hận thù dai thế
#
# Assistant Response: KHONG_PHAN_DONG
# Giải thích: Bình luận "bạn hận thù dai thế" là một câu hỏi hoặc nhận xét cá nhân về cảm xúc của người khác, không trực tiếp thể hiện quan điểm chống phá nhà nước Việt Nam hay ủng hộ các lực lượng đối lập. Nó không mang tính chất tuyên truyền, kích động hay xuyên tạc chính sách của nhà nước. Do đó, bình luận này thuộc nhóm KHONG_PHAN_DONG.
#
# Predicted: KHONG_PHAN_DONG | Actual: KHONG_LIEN_QUAN | ✗
#
# === Progress Update ===
# Processed 200 samples. Current accuracy: 0.5950
# ========================================
#
# -----------------------------------------Sample 201:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Một người ăn hết 100 cuốn chả giò.
#
# 2. Vấn đề: Không rõ mục đích, có thể là thử thách hoặc khoe khoang.
#
# 3. Phản động/tin giả: không, nội dung vô thưởng vô phạt.
# Comment: tức tức tức hơn ăn ớt
#
# Assistant Response: KHONG_LIEN_QUAN
# Giải thích: Bình luận "tức tức tức hơn ăn ớt" chỉ thể hiện cảm xúc cá nhân về việc ăn nhiều chả giò, không mang tính chất phản động hay chống phá nhà nước Việt Nam. Nó chỉ là một ý kiến chủ quan về trải nghiệm ăn uống mà thôi.
#
# Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# -----------------------------------------Sample 202:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Văn bản ca ngợi một "đội hình" các nhân vật lịch sử đã "cứu nước" trong giai đoạn khó khăn của Việt Nam.
# 2. Vấn đề: Sử dụng ngôn ngữ mang tính chất tuyên truyền, ca ngợi một cách chung chung mà không nêu rõ bối cảnh lịch sử cụ thể.
# 3. Phản động/tin giả: không, văn bản mang tính chất ca ngợi lịch sử, không có dấu hiệu xuyên tạc hay kích động.
# Comment: đời đời ghi nhớ công ơn trời biển của bác hồ và các anh hùng liệt sĩ và các anh chị đã đỗ mồ hôi xương máu để dành lấy quyền tự do cho nhân loại và giữ non sông gấm vóc của chúng ta ạ
#
# Assistant Response: KHONG_PHAN_DONG
# Giải thích: Bình luận bày tỏ lòng biết ơn và tôn vinh những người đã hy sinh vì đất nước, phù hợp với quan điểm chính thống về lịch sử và sự nghiệp cách mạng. Không có nội dung chống phá hay xuyên tạc lịch sử.
#
# Predicted: KHONG_PHAN_DONG | Actual: KHONG_PHAN_DONG | ✓
#
# -----------------------------------------Sample 203:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Một người đang tuyên truyền ở Cali thì bị cảnh sát bắt.
#
# 2. Vấn đề: Hoạt động tuyên truyền bất hợp pháp ở Cali dẫn đến việc bị cảnh sát can thiệp.
#
# 3. Phản động/tin giả: Không rõ ràng. Cần biết nội dung tuyên truyền là gì để xác định. Nếu nội dung chống phá nhà nước Việt Nam thì có thể coi là phản động.
# Comment: ngô kỷ đang hỏi chuyên đề đâu hử
#
# Assistant Response: KHONG_LIEN_QUAN
# Giải thích: Bình luận chỉ đơn thuần hỏi về chuyên đề của Ngô Kỷ mà không liên quan đến nội dung chính của bài đăng về việc bắt giữ người tuyên truyền bất hợp pháp. Không thể xác định tính chất phản động từ câu hỏi này.
#
# Predicted: KHONG_LIEN_QUAN | Actual: KHONG_LIEN_QUAN | ✓
#
# -----------------------------------------Sample 204:-----------------------------------------
# Post:
# 1. Nội dung sơ lược: Ảnh Sài Gòn năm 1973 với lượng xe máy ít hơn hiện nay, mời xem thêm ảnh đẹp ở phần bình luận.
# 2. Vấn đề: Không có vấn đề chính trị rõ ràng.
# 3. Phản động/tin giả: không, nội dung mang tính chất hoài niệm về quá khứ.
# Comment: thôi bạn nói với cái lũ phải ủng hộ mỳ tôm sắp hết hạn cho ngày kỷ niệm tụt quần nghe mà nó chối lắm
#
# Assistant Response: KHONG_PHAN_DONG
# Giải thích: Bình luận sử dụng ngôn ngữ thô tục và chế giễu, nhưng không trực tiếp thể hiện quan điểm chống phá nhà nước Việt Nam. Nó có thể ám chỉ đến các hoạt động kỷ niệm hoặc sự kiện nào đó, nhưng không rõ ràng và mang tính chất cá nhân, không liên quan đến vấn đề chính trị hay chống phá chế độ.
#
# Predicted: KHONG_PHAN_DONG | Actual: KHONG_LIEN_QUAN | ✗
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 38
#      35 inputs = tokenizer_sft([formatted_input], return_tensors="pt").to(model_sft.device)
#      37 # Generate response
# ---> 38 output_ids = model_sft.generate(
#      39     **inputs,
#      40     max_new_tokens=256,
#      41     do_sample=True,
#      42     top_p=0.8,
#      43     top_k=20,
#      44     temperature=0.4,
#      45     repetition_penalty=1.05,
#      46     pad_token_id=tokenizer_sft.eos_token_id,
#      47     eos_token_id=tokenizer_sft.eos_token_id
#      48 )
#      50 # Decode the response
#      51 assistant_response = tokenizer_sft.decode(
#      52     output_ids[0, inputs.input_ids.shape[1]:],
#      53     skip_special_tokens=True
#      54 ).strip()
#
# File /venv/main/lib/python3.12/site-packages/peft/peft_model.py:1968, in PeftModelForCausalLM.generate(self, *args, **kwargs)
#    1966     with self._enable_peft_forward_hooks(*args, **kwargs):
#    1967         kwargs = {k: v for k, v in kwargs.items() if k not in self.special_peft_forward_args}
# -> 1968         outputs = self.base_model.generate(*args, **kwargs)
#    1969 else:
#    1970     outputs = self.base_model.generate(**kwargs)
#
# File /venv/main/lib/python3.12/site-packages/unsloth/models/llama.py:1742, in unsloth_fast_generate(self, *args, **kwargs)
#    1740 # Mixed precision autocast
#    1741 with torch.inference_mode(), torch.autocast(device_type = DEVICE_TYPE, dtype = dtype):
# -> 1742     output = self._old_generate(*args, **kwargs)
#    1743 pass
#    1745 # Return accelerate back
#    1746 # if accelerate_new_send_to_device is not None:
#    1747 #     accelerate.utils.operations.send_to_device = accelerate_old_send_to_device
#    1748 # pass
#
# File /venv/main/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File /venv/main/lib/python3.12/site-packages/transformers/generation/utils.py:2633, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, custom_generate, **kwargs)
#    2625     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2626         input_ids=input_ids,
#    2627         expand_size=generation_config.num_return_sequences,
#    2628         is_encoder_decoder=self.config.is_encoder_decoder,
#    2629         **model_kwargs,
#    2630     )
#    2632     # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2633     result = self._sample(
#    2634         input_ids,
#    2635         logits_processor=prepared_logits_processor,
#    2636         stopping_criteria=prepared_stopping_criteria,
#    2637         generation_config=generation_config,
#    2638         synced_gpus=synced_gpus,
#    2639         streamer=streamer,
#    2640         **model_kwargs,
#    2641     )
#    2643 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2644     # 11. interleave input_ids with `num_beams` additional sequences per batch
#    2645     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2646         input_ids=input_ids,
#    2647         expand_size=generation_config.num_beams,
#    2648         is_encoder_decoder=self.config.is_encoder_decoder,
#    2649         **model_kwargs,
#    2650     )
#
# File /venv/main/lib/python3.12/site-packages/transformers/generation/utils.py:3617, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3615     is_prefill = False
#    3616 else:
# -> 3617     outputs = model_forward(**model_inputs, return_dict=True)
#    3619 # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#    3620 model_kwargs = self._update_model_kwargs_for_generation(
#    3621     outputs,
#    3622     model_kwargs,
#    3623     is_encoder_decoder=self.config.is_encoder_decoder,
#    3624 )
#
# File /venv/main/lib/python3.12/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /venv/main/lib/python3.12/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /venv/main/lib/python3.12/site-packages/unsloth/models/llama.py:1127, in CausalLM_fast_forward.<locals>._CausalLM_fast_forward(self, input_ids, causal_mask, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, num_logits_to_keep, logits_to_keep, *args, **kwargs)
#    1109 def _CausalLM_fast_forward(
#    1110     self,
#    1111     input_ids: torch.LongTensor = None,
#    (...)   1124     *args, **kwargs,
#    1125 ) -> Union[Tuple, CausalLMOutputWithPast]:
#    1126     if past_key_values is not None:
# -> 1127         outputs = fast_forward_inference(
#    1128             self,
#    1129             input_ids,
#    1130             past_key_values,
#    1131             position_ids = position_ids,
#    1132             attention_mask = attention_mask,
#    1133         )
#    1134     else:
#    1135         causal_mask = xformers.attn_bias.LowerTriangularMask() if HAS_XFORMERS else None
#
# File /venv/main/lib/python3.12/site-packages/unsloth/models/llama.py:1060, in _LlamaModel_fast_forward_inference.<locals>.LlamaModel_fast_forward_inference_custom(self, input_ids, past_key_values, position_ids, attention_mask)
#    1052 residual.copy_(X) # residual = X
#    1053 X = fast_rms_layernorm_inference(
#    1054     decoder_layer.input_layernorm,
#    1055     X,
#    (...)   1058     variance = variance,
#    1059 )
# -> 1060 X, present_key_value = attention_fast_forward_inference(
#    1061     decoder_layer.self_attn,
#    1062     hidden_states = X,
#    1063     past_key_value = past_key_values[idx],
#    1064     position_ids = position_ids,
#    1065     attention_mask = attention_mask,
#    1066     do_prefill = not hasattr(decoder_layer.self_attn, "paged_attention"),
#    1067 )
#    1068 X += residual
#    1070 residual.copy_(X) # residual = X
#
# File /venv/main/lib/python3.12/site-packages/unsloth/models/qwen3.py:282, in Qwen3Attention_fast_forward_inference(self, hidden_states, past_key_value, position_ids, do_prefill, attention_mask)
#     279     self.attention.resize_((bsz, n_heads, 1, self.attention.shape[-1]+KV_CACHE_INCREMENT))
#     280 pass
# --> 282 Qn = fast_linear_forward(self.q_proj, Xn, out = self.temp_QA[0])
#     283 Kn = fast_linear_forward(self.k_proj, Xn, out = self.temp_KV[0])
#     284 Vn = fast_linear_forward(self.v_proj, Xn, out = self.temp_KV[1])
#
# File /venv/main/lib/python3.12/site-packages/unsloth/kernels/utils.py:680, in fast_linear_forward(proj, X, temp_lora, out)
#     678 if bsz == 1:
#     679     out = out.view(out_dim)
# --> 680     temp_lora = torch_mv(lora_A._fast_lora, X.ravel(), out = temp_lora)
#     681     out.addmv_(lora_B._fast_lora, temp_lora, alpha = lora_S)
#     682 else:
#
# KeyboardInterrupt:

# %% [markdown]
# # Live predicting

# %%
conversation = [{"role": "system", "content": SYSTEM_PROMPT_CONTENT }]
while True:
    post = input("Nội dung bài viết: ")
    comment = input("Bình luận cần đánh giá: ")
    if post.lower() == "reset":
        conversation = [{"role": "system", "content": SYSTEM_PROMPT_CONTENT }]
        print("The chat history has been cleared!")
        continue

    conversation.append({"role": "user", "content": create_user_content(post,comment) })
    input_ids = ft_tokenizer.apply_chat_template(conversation, return_tensors="pt").to(ft_model.device)

    out_ids = ft_model.generate(
        input_ids=input_ids,
        max_new_tokens=768,
        do_sample=True,
        top_p=0.95,
        top_k=40,
        temperature=0.1,
        repetition_penalty=1.05,
    )
    assistant = ft_tokenizer.batch_decode(out_ids[:, input_ids.size(1): ], skip_special_tokens=True)[0].strip()
    print("Assistant: ", assistant)
    conversation.append({"role": "assistant", "content": assistant })
